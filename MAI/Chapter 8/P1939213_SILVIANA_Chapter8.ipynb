# %% [markdown]
# # Practical 8: Applications of Derivative

# %% [markdown]
# ### Example in Section 8.6 in course notes
# Suppose we have a univariate function given by: $f(x)=4x^2-4x+3$.<br>
# Let us choose to start with $x_0=2$ and learning rate $\alpha = 0.1$. Suppose also that we choose a threshold (also called **epsilon**) of 0.001, meaning that we stop the iterations when the difference between two x-values is less than epsilon.<br>
# Recall that $\frac{df}{dx}=f'(x)=8x-4$.

# %%
x = 2 # Starting value of x
rate = 0.1 # Set learning rate
epsilon = 0.001 # Stop algorithm when absolute difference between 2 consecutive x-values is less than epsilon
diff = 1 # difference between 2 consecutive iterates
max_iter = 1000 # set maximum number of iterations
iter = 1 # iterations counter
f = lambda x: 4*x**2-4*x+3
deriv = lambda x: 8*x-4 # derivative of f

# Now Gradient Descent

while diff > epsilon and iter < max_iter:
    x_new = x - rate * deriv(x)
    print("Iteration ", iter, ": x-value is: ", x_new,"f(x) is: ", f(x_new) )
    diff = abs(x_new - x)
    iter = iter + 1
    x = x_new
    
print("The local minimum occurs at: ", x)
# Out:
# Iteration  1 : x-value is:  0.7999999999999998 f(x) is:  2.3599999999999994
# Iteration  2 : x-value is:  0.5599999999999999 f(x) is:  2.0144
# Iteration  3 : x-value is:  0.512 f(x) is:  2.0005759999999997
# Iteration  4 : x-value is:  0.5024 f(x) is:  2.0000230400000003
# Iteration  5 : x-value is:  0.50048 f(x) is:  2.0000009216
# Iteration  6 : x-value is:  0.500096 f(x) is:  2.000000036864
# The local minimum occurs at:  0.500096

# %% [markdown]
# ### Example 11
# Repeat the Example with $f(x)=4x^2-4x+3$ above, starting with $x_0=2$, but this time with a learning rate of $\alpha = 0.001$. Choose an epsilon value of 0.000001 and set the maximum number of iterations to be 2000. Comment on your results.

# %% [markdown]
# ### Example 12
# Let $f(x)=x^5-30x^3+50x$. Use gradient descent to find the minimum of $f$ with each of the following.<br>
# (a) Start with $x_0=0$<br>
# (b) Start with $x_0=2$<br>
# In each, use a learning rate of 0.001, epsilon 0.001, and set the maximum number of iterations to 1000. Comment on your results.

# %% [markdown]
# **Part (a)**

# %%
x = 0 # Starting value of x
rate = 0.001 # Set learning rate
precision = 0.001 # Stop algorithm when absolute difference between 2 consecutive x-values is less than precision
diff = 1 # difference between 2 consecutive iterates
max_iter = 1000 # set maximum number of iterations
iter = 1 # iterations counter
f = lambda x: x**5-30*x**3+50*x
deriv = lambda x: 5*x**4-90*x**2+50 # derivative of f

# Now Gradient Descent

while diff > precision and iter < max_iter:
    x_new = x - rate * deriv(x)
    print("Iteration ", iter, ": x-value is: ", x_new,"f(x) is: ", f(x_new) )
    diff = abs(x_new - x)
    iter = iter + 1
    x = x_new
    
print("The local minimum occurs at: ", x)
# Out:
# Iteration  1 : x-value is:  -0.05 f(x) is:  -2.4962503125
# Iteration  2 : x-value is:  -0.09977503125000001 f(x) is:  -4.9589634672387275
# Iteration  3 : x-value is:  -0.14887957164830107 f(x) is:  -7.345053688136462
# Iteration  4 : x-value is:  -0.19688716669566703 f(x) is:  -9.615686884933888
# Iteration  5 : x-value is:  -0.24340587007298486 f(x) is:  -11.73852011720569
# Iteration  6 : x-value is:  -0.28809124318022994 f(x) is:  -13.689229152782108
# Iteration  7 : x-value is:  -0.3306559945329968 f(x) is:  -15.452200127136589
# Iteration  8 : x-value is:  -0.37087575867540135 f(x) is:  -17.020399002180167
# Iteration  9 : x-value is:  -0.40859096252276045 f(x) is:  -18.394550180885986
# Iteration  10 : x-value is:  -0.44370512659773126 f(x) is:  -19.581830824618304
# Iteration  11 : x-value is:  -0.47618024238514733 f(x) is:  -20.594312535205802
# Iteration  12 : x-value is:  -0.5060300287169497 f(x) is:  -21.447363342844284
# Iteration  13 : x-value is:  -0.5333119036005989 f(x) is:  -22.158175255197868
# Iteration  14 : x-value is:  -0.5581184390080091 f(x) is:  -22.74452306180511
# Iteration  15 : x-value is:  -0.580568931119573 f(x) is:  -23.223802919945534
# Iteration  16 : x-value is:  -0.6008015537537676 f(x) is:  -23.612353432704577
# Iteration  17 : x-value is:  -0.6189663977816761 f(x) is:  -23.92503099395747
# Iteration  18 : x-value is:  -0.6352195540185678 f(x) is:  -24.17499454027582
# Iteration  19 : x-value is:  -0.6497182815690572 f(x) is:  -24.37364961745079
# Iteration  20 : x-value is:  -0.6626172203997851 f(x) is:  -24.53070417513584
# Iteration  21 : x-value is:  -0.6740655534889974 f(x) is:  -24.654295348434676
# Iteration  22 : x-value is:  -0.6842049950584058 f(x) is:  -24.751155039109754
# Iteration  23 : x-value is:  -0.693168471082105 f(x) is:  -24.826790619826696
# Iteration  24 : x-value is:  -0.7010793607497214 f(x) is:  -24.88566456922625
# Iteration  25 : x-value is:  -0.7080511780016331 f(x) is:  -24.931362889920678
# Iteration  26 : x-value is:  -0.7141875869254948 f(x) is:  -24.966746719439776
# Iteration  27 : x-value is:  -0.7195826610447794 f(x) is:  -24.99408477194831
# Iteration  28 : x-value is:  -0.7243213125869798 f(x) is:  -25.015166388686296
# Iteration  29 : x-value is:  -0.7284798326422894 f(x) is:  -25.03139628391653
# Iteration  30 : x-value is:  -0.7321264961756374 f(x) is:  -25.043872782199887
# Iteration  31 : x-value is:  -0.7353221969461607 f(x) is:  -25.053451642429334
# Iteration  32 : x-value is:  -0.7381210865482838 f(x) is:  -25.06079760069254
# Iteration  33 : x-value is:  -0.7405711991730618 f(x) is:  -25.066425644445076
# Iteration  34 : x-value is:  -0.742715049514017 f(x) is:  -25.070733828731385
# Iteration  35 : x-value is:  -0.7445901957441673 f(x) is:  -25.07402921017795
# Iteration  36 : x-value is:  -0.74622976289979 f(x) is:  -25.07654823664344
# Iteration  37 : x-value is:  -0.7476629245308597 f(x) is:  -25.078472707263586
# Iteration  38 : x-value is:  -0.7489153423005702 f(x) is:  -25.079942218023618
# Iteration  39 : x-value is:  -0.75000956449125 f(x) is:  -25.081063835228058
# Iteration  40 : x-value is:  -0.7509653852286368 f(x) is:  -25.081919593264473
# The local minimum occurs at:  -0.7509653852286368

# %% [markdown]
# **Part(b)**

# %%
x = 2 # Starting value of x
rate = 0.001 # Set learning rate
precision = 0.001 # Stop algorithm when absolute difference between 2 consecutive x-values is less than precision
diff = 1 # difference between 2 consecutive iterates
max_iter = 1000 # set maximum number of iterations
iter = 1 # iterations counter
f = lambda x: x**5-30*x**3+50*x
deriv = lambda x: 5*x**4-90*x**2+50 # derivative of f

# Now Gradient Descent

while diff > precision and iter < max_iter:
    x_new = x - rate * deriv(x)
    print("Iteration ", iter, ": x-value is: ", x_new,"f(x) is: ", f(x_new) )
    diff = abs(x_new - x)
    iter = iter + 1
    x = x_new
    
print("The local minimum occurs at: ", x)
# Out:
# Iteration  1 : x-value is:  2.23 f(x) is:  -166.03970226570004
# Iteration  2 : x-value is:  2.50391232795 f(x) is:  -247.33574188131556
# Iteration  3 : x-value is:  2.8216362776825648 f(x) is:  -354.00634122013867
# Iteration  4 : x-value is:  3.171245229725892 f(x) is:  -477.47770476930145
# Iteration  5 : x-value is:  3.520661137552822 f(x) is:  -592.2254105762388
# Iteration  6 : x-value is:  3.818029150533915 f(x) is:  -667.4730642648359
# Iteration  7 : x-value is:  4.017495175367675 f(x) is:  -697.8380685473041
# Iteration  8 : x-value is:  4.117578076645015 f(x) is:  -704.8475432688065
# Iteration  9 : x-value is:  4.1562117648945645 f(x) is:  -705.8431528389654
# Iteration  10 : x-value is:  4.168908422393485 f(x) is:  -705.9486285945052
# Iteration  11 : x-value is:  4.172803397193701 f(x) is:  -705.958491051829
# Iteration  12 : x-value is:  4.173970434098405 f(x) is:  -705.9593747061026
# Iteration  13 : x-value is:  4.174317556156385 f(x) is:  -705.9594528362722
# The local minimum occurs at:  4.174317556156385

# %% [markdown]
# **Graph for Example 12**

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-6,6,100)
y = x**5 -30*x**3+50*x
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Task 1

# %% [markdown]
# Use Matplotlib in Python to graph each of the following functions $f$. Then estimate the global
# maximum and minimum values of $f$ (if any) on the given interval. Also state where those values
# occur.

# %% [markdown]
# (a) $f(x)=4x^3-3x^4$; $(-\infty, \infty)$

# %%
x = np.linspace(-1, 2, 1000)
y = (4*x**3) - (3*x**4)

plt.plot(x, y)
plt.show()

# %% [markdown]
# Global Maximum: (1, 1)
#
# Global Minimum: None

# %% [markdown]
# (b) $f(x)=(x^2-1)^2$; $(-\infty, \infty)$

# %%
x = np.linspace(-1.5,1.5,1000)
y = (x**2 - 1)**2

plt.plot(x, y)
plt.show()

# %% [markdown]
# Global Maximum: None
#
# Global Minimum value = 0 at x = +-1

# %% [markdown]
# (c) $f(x)=1+\frac{1}{x}$; $(0, \infty)$

# %%
x = np.linspace(0,10,1000)
y = 1 + 1/x

plt.plot(x, y)
plt.show()
# Out:
# C:\Users\Silviana\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide

# %% [markdown]
# No maximum or minimum

# %% [markdown]
# ### Task 2

# %% [markdown]
# Let $f(x)=x^4-3x^3+15$. Implement gradient descent in Python to find the global minimum of $f$, and
# state where it occurs.<br><br>
# (a) Start the search at $x_0=6$ with the following settings: learning rate $\alpha=0.01$, epsilon =  0.00001, and the maximum number of iterations = 10000.

# %%
x = 6
alpha = 0.01
epsilon = 0.00001
diff = 1
max_iter = 10000
iter = 1

f = lambda x: x**4 - 3*x**3 + 15
deriv = lambda x: 4*x**3 - 9*x**2

while diff > epsilon:
    x_n = x - alpha * deriv(x)
    print("Iteration ", iter, ": x-value is: ", x_n,"f(x) is: ", f(x_n) )
    diff = abs(x_n-x)
    iter += 1
    x = x_n

print("The local minimum occurs at: ", x)
# Out:
# Iteration  1 : x-value is:  0.5999999999999996 f(x) is:  14.4816
# Iteration  2 : x-value is:  0.6237599999999996 f(x) is:  14.423309408830677
# Iteration  3 : x-value is:  0.6490692731402646 f(x) is:  14.357145064124976
# Iteration  4 : x-value is:  0.6760475763767438 f(x) is:  14.2819428460233
# Iteration  5 : x-value is:  0.704821965498881 f(x) is:  14.196372722391306
# Iteration  6 : x-value is:  0.7355261366038248 f(x) is:  14.098923544913854
# Iteration  7 : x-value is:  0.7682992721113444 f(x) is:  13.98789115491834
# Iteration  8 : x-value is:  0.8032842278686305 f(x) is:  13.861372711879772
# Iteration  9 : x-value is:  0.840624861847519 f(x) is:  13.717271371076762
# Iteration  10 : x-value is:  0.8804622684298664 f(x) is:  13.553316926425905
# Iteration  11 : x-value is:  0.9229296507309586 f(x) is:  13.367109726374046
# Iteration  12 : x-value is:  0.9681455460305634 f(x) is:  13.156196857849718
# Iteration  13 : x-value is:  1.016205130521792 f(x) is:  12.918190853156041
# Iteration  14 : x-value is:  1.067169389942697 f(x) is:  12.650941275077223
# Iteration  15 : x-value is:  1.1210520795330405 f(x) is:  12.352767362098614
# Iteration  16 : x-value is:  1.1778046421472836 f(x) is:  12.022753996200674
# Iteration  17 : x-value is:  1.237299637824332 f(x) is:  11.661102006499993
# Iteration  18 : x-value is:  1.2993137782331108 f(x) is:  11.269506180871783
# Iteration  19 : x-value is:  1.3635123370474889 f(x) is:  10.851510922419774
# Iteration  20 : x-value is:  1.429437442158506 f(x) is:  10.412768047901803
# Iteration  21 : x-value is:  1.4965033788967752 f(x) is:  9.961102064343414
# Iteration  22 : x-value is:  1.5640022802344904 f(x) is:  9.506287904085877
# Iteration  23 : x-value is:  1.6311231270849003 f(x) is:  9.059477808598164
# Iteration  24 : x-value is:  1.6969855549473505 f(x) is:  8.632284274871218
# Iteration  25 : x-value is:  1.7606875094969714 f(x) is:  8.235624985415008
# Iteration  26 : x-value is:  1.821362659674955 f(x) is:  7.87853274025885
# Iteration  27 : x-value is:  1.8782404675959476 f(x) is:  7.567184565052369
# Iteration  28 : x-value is:  1.930700009196379 f(x) is:  7.3043738973422165
# Iteration  29 : x-value is:  1.9783089472809865 f(x) is:  7.089536414463046
# Iteration  30 : x-value is:  2.0208417065692057 f(x) is:  6.91928488856464
# Iteration  31 : x-value is:  2.0582751831448975 f(x) is:  6.788276293766362
# Iteration  32 : x-value is:  2.090764845528107 f(x) is:  6.690176750574956
# Iteration  33 : x-value is:  2.118607415721545 f(x) is:  6.618517231234826
# Iteration  34 : x-value is:  2.1421976265432066 f(x) is:  6.567315636219369
# Iteration  35 : x-value is:  2.1619858762300224 f(x) is:  6.53143362756639
# Iteration  36 : x-value is:  2.178441640823547 f(x) is:  6.506705003182965
# Iteration  37 : x-value is:  2.1920251576443675 f(x) is:  6.489904356314433
# Iteration  38 : x-value is:  2.203167862727841 f(x) is:  6.478626420039166
# Iteration  39 : x-value is:  2.2122606942724694 f(x) is:  6.4711313599565905
# Iteration  40 : x-value is:  2.2196486877629633 f(x) is:  6.46619151226248
# Iteration  41 : x-value is:  2.2256301304909205 f(x) is:  6.462957906212601
# Iteration  42 : x-value is:  2.2304587076907274 f(x) is:  6.460852977158865
# Iteration  43 : x-value is:  2.234347382687595 f(x) is:  6.459488970104669
# Iteration  44 : x-value is:  2.2374730902946083 f(x) is:  6.458608330129401
# Iteration  45 : x-value is:  2.239981621916576 f(x) is:  6.458041451913985
# Iteration  46 : x-value is:  2.2419923174775156 f(x) is:  6.457677418419223
# Iteration  47 : x-value is:  2.243602351591089 f(x) is:  6.457444095834187
# Iteration  48 : x-value is:  2.2448905184851697 f(x) is:  6.457294781691928
# Iteration  49 : x-value is:  2.2459204946033684 f(x) is:  6.457199346859625
# Iteration  50 : x-value is:  2.2467436015363202 f(x) is:  6.457138409750698
# Iteration  51 : x-value is:  2.2474011148628947 f(x) is:  6.457099531040271
# Iteration  52 : x-value is:  2.2479261740485823 f(x) is:  6.457074741639431
# Iteration  53 : x-value is:  2.2483453500247714 f(x) is:  6.457058943724952
# Iteration  54 : x-value is:  2.2486799240099864 f(x) is:  6.457048880032115
# Iteration  55 : x-value is:  2.2489469258218673 f(x) is:  6.457042471267194
# Iteration  56 : x-value is:  2.2491599737759116 f(x) is:  6.45703839109002
# Iteration  57 : x-value is:  2.2493299520940697 f(x) is:  6.457035793957722
# Iteration  58 : x-value is:  2.249465555993498 f(x) is:  6.457034141091917
# Iteration  59 : x-value is:  2.24957372949745 f(x) is:  6.457033089314024
# Iteration  60 : x-value is:  2.249660016570137 f(x) is:  6.457032420100141
# Iteration  61 : x-value is:  2.2497288424102844 f(x) is:  6.457031994335573
# Iteration  62 : x-value is:  2.24978373858824 f(x) is:  6.457031723475421
# Iteration  63 : x-value is:  2.2498275231061067 f(x) is:  6.457031551170541
# Iteration  64 : x-value is:  2.249862444322635 f(x) is:  6.457031441565224
# Iteration  65 : x-value is:  2.249890295941524 f(x) is:  6.457031371846252
# Iteration  66 : x-value is:  2.2499125088471215 f(x) is:  6.457031327499841
# Iteration  67 : x-value is:  2.24993022442776 f(x) is:  6.457031299292851
# Iteration  68 : x-value is:  2.249944353104799 f(x) is:  6.45703128135181
# Iteration  69 : x-value is:  2.2499556210437 f(x) is:  6.457031269940586
# Iteration  70 : x-value is:  2.2499646074278457 f(x) is:  6.457031262682655
# The local minimum occurs at:  2.2499646074278457

# %% [markdown]
# (b) Start the search at $x_0=6$ with the following settings: learning rate $\alpha=0.001$, epsilon =  0.00001, and the maximum number of iterations = 10000.

# %%
x = 6
alpha = 0.001
epsilon = 0.00001
diff = 1
max_iter = 10000
iter = 1

f = lambda x: x**4 - 3*x**3 + 15
deriv = lambda x: 4*x**3 - 9*x**2

while diff > epsilon:
    x_n = x - alpha * deriv(x)
    print("Iteration ", iter, ": x-value is: ", x_n,"f(x) is: ", f(x_n) )
    diff = abs(x_n-x)
    iter += 1
    x = x_n

print("The local minimum occurs at: ", x)
# Out:
# Iteration  1 : x-value is:  5.46 f(x) is:  415.41748656000004
# Iteration  2 : x-value is:  5.077219056 f(x) is:  286.8691956163293
# Iteration  3 : x-value is:  4.7856971105651365 f(x) is:  210.72370178496004
# Iteration  4 : x-value is:  4.55339787326223 f(x) is:  161.6525123211913
# Iteration  5 : x-value is:  4.362368498794202 f(x) is:  128.09974843454233
# Iteration  6 : x-value is:  4.201572820934333 f(x) is:  104.12217594671333
# Iteration  7 : x-value is:  4.063766689032126 f(x) is:  86.38922788098643
# Iteration  8 : x-value is:  3.943955067763642 f(x) is:  72.90915101358519
# Iteration  9 : x-value is:  3.8385586634455064 f(x) is:  62.42834787804543
# Iteration  10 : x-value is:  3.7449319857105268 f(x) is:  54.124466274358525
# Iteration  11 : x-value is:  3.661069198026341 f(x) is:  47.43924477640178
# Iteration  12 : x-value is:  3.5854165422784474 f(x) is:  41.98260302172022
# Iteration  13 : x-value is:  3.516748292407647 f(x) is:  37.47516588902403
# Iteration  14 : x-value is:  3.4540821603786127 f(x) is:  33.71252661540781
# Iteration  15 : x-value is:  3.3966200673844655 f(x) is:  30.54231108616618
# Iteration  16 : x-value is:  3.3437057166338358 f(x) is:  27.849046435260647
# Iteration  17 : x-value is:  3.2947935874035488 f(x) is:  25.543933745817128
# Iteration  18 : x-value is:  3.249425871591936 f(x) is:  23.55778557126645
# Iteration  19 : x-value is:  3.2072150459678404 f(x) is:  21.83605468905509
# Iteration  20 : x-value is:  3.167830515792172 f(x) is:  20.33527418888829
# Iteration  21 : x-value is:  3.1309882475409334 f(x) is:  19.020468318713696
# Iteration  22 : x-value is:  3.0964426283628796 f(x) is:  17.863242625732838
# Iteration  23 : x-value is:  3.063980006434812 f(x) is:  16.840356928595057
# Iteration  24 : x-value is:  3.033413515580717 f(x) is:  15.932646413394195
# Iteration  25 : x-value is:  3.004578892017906 f(x) is:  15.124197037749909
# Iteration  26 : x-value is:  2.9773310653761236 f(x) is:  14.40170896321618
# Iteration  27 : x-value is:  2.951541359666197 f(x) is:  13.754000567857616
# Iteration  28 : x-value is:  2.9270951789390374 f(x) is:  13.171618654779351
# Iteration  29 : x-value is:  2.9038900812165425 f(x) is:  12.646529655719277
# Iteration  30 : x-value is:  2.88183416579972 f(x) is:  12.171873163907321
# Iteration  31 : x-value is:  2.8608447152843492 f(x) is:  11.741763834351303
# Iteration  32 : x-value is:  2.8408470459601665 f(x) is:  11.351131111884499
# Iteration  33 : x-value is:  2.821773529745893 f(x) is:  10.995588761923557
# Iteration  34 : x-value is:  2.803562758146137 f(x) is:  10.671328043978065
# Iteration  35 : x-value is:  2.7861588244355797 f(x) is:  10.375029763499796
# Iteration  36 : x-value is:  2.769510704768632 f(x) is:  10.103791490540466
# Iteration  37 : x-value is:  2.7535717224661393 f(x) is:  9.85506703426293
# Iteration  38 : x-value is:  2.738299082559317 f(x) is:  9.626615875583234
# Iteration  39 : x-value is:  2.7236534659364495 f(x) is:  9.41646073323777
# Iteration  40 : x-value is:  2.7095986742627165 f(x) is:  9.222851805851704
# Iteration  41 : x-value is:  2.69610131832149 f(x) is:  9.044236519560535
# Iteration  42 : x-value is:  2.6831305436287654 f(x) is:  8.879233836306739
# Iteration  43 : x-value is:  2.6706577881569578 f(x) is:  8.72661235624571
# Iteration  44 : x-value is:  2.6586565678136687 f(x) is:  8.585271589414873
# Iteration  45 : x-value is:  2.6471022859893707 f(x) is:  8.454225885038191
# Iteration  46 : x-value is:  2.635972064042245 f(x) is:  8.33259059773431
# Iteration  47 : x-value is:  2.625244590049948 f(x) is:  8.219570143215805
# Iteration  48 : x-value is:  2.614899983543948 f(x) is:  8.11444765547455
# Iteration  49 : x-value is:  2.604919674265854 f(x) is:  8.016576005793588
# Iteration  50 : x-value is:  2.595286293257836 f(x) is:  7.925369983430528
# Iteration  51 : x-value is:  2.5859835748296693 f(x) is:  7.840299470226881
# Iteration  52 : x-value is:  2.5769962681403173 f(x) is:  7.760883468089055
# Iteration  53 : x-value is:  2.568310057298151 f(x) is:  7.686684860347704
# Iteration  54 : x-value is:  2.5599114890256915 f(x) is:  7.61730580630185
# Iteration  55 : x-value is:  2.5517879070560943 f(x) is:  7.552383683484706
# Iteration  56 : x-value is:  2.5439273925327095 f(x) is:  7.491587504906789
# Iteration  57 : x-value is:  2.5363187097726536 f(x) is:  7.434614749184938
# Iteration  58 : x-value is:  2.528951256832619 f(x) is:  7.381188550417512
# Iteration  59 : x-value is:  2.521815020382014 f(x) is:  7.331055202209086
# Iteration  60 : x-value is:  2.5149005344465074 f(x) is:  7.283981936622844
# Iteration  61 : x-value is:  2.5081988426354296 f(x) is:  7.239754944240495
# Iteration  62 : x-value is:  2.5017014635103965 f(x) is:  7.198177606099414
# Iteration  63 : x-value is:  2.495400358790842 f(x) is:  7.1590689121865765
# Iteration  64 : x-value is:  2.4892879041256855 f(x) is:  7.122262044507295
# Iteration  65 : x-value is:  2.4833568621897655 f(x) is:  7.087603105604877
# Iteration  66 : x-value is:  2.4776003578895125 f(x) is:  7.054949975859643
# Iteration  67 : x-value is:  2.472011855485068 f(x) is:  7.024171285004236
# Iteration  68 : x-value is:  2.4665851374561254 f(x) is:  6.99514548510966
# Iteration  69 : x-value is:  2.4613142849564915 f(x) is:  6.96776001386614
# Iteration  70 : x-value is:  2.4561936597180534 f(x) is:  6.941910538341396
# Iteration  71 : x-value is:  2.4512178872787556 f(x) is:  6.91750027057671
# Iteration  72 : x-value is:  2.446381841421546 f(x) is:  6.894439347405232
# Iteration  73 : x-value is:  2.4416806297222458 f(x) is:  6.872644267767392
# Iteration  74 : x-value is:  2.4371095801140967 f(x) is:  6.85203738157621
# Iteration  75 : x-value is:  2.432664228385483 f(x) is:  6.832546424863459
# Iteration  76 : x-value is:  2.428340306535143 f(x) is:  6.814104096532645
# Iteration  77 : x-value is:  2.4241337319161835 f(x) is:  6.796647672565321
# Iteration  78 : x-value is:  2.42004059710648 f(x) is:  6.7801186539849425
# Iteration  79 : x-value is:  2.416057160448677 f(x) is:  6.764462445285076
# Iteration  80 : x-value is:  2.412179837208069 f(x) is:  6.749628060382925
# Iteration  81 : x-value is:  2.4084051913011955 f(x) is:  6.735567853472446
# Iteration  82 : x-value is:  2.404729927552086 f(x) is:  6.7222372724274635
# Iteration  83 : x-value is:  2.40115088443681 f(x) is:  6.709594632649754
# Iteration  84 : x-value is:  2.3976650272803175 f(x) is:  6.697600909474126
# Iteration  85 : x-value is:  2.394269441872601 f(x) is:  6.6862195474346535
# Iteration  86 : x-value is:  2.3909613284739435 f(x) is:  6.675416284867282
# Iteration  87 : x-value is:  2.3877379961815066 f(x) is:  6.66515899247603
# Iteration  88 : x-value is:  2.384596857631776 f(x) is:  6.6554175246257685
# Iteration  89 : x-value is:  2.3815354240154236 f(x) is:  6.646163582245144
# Iteration  90 : x-value is:  2.378551300383023 f(x) is:  6.63737058633135
# Iteration  91 : x-value is:  2.3756421812217483 f(x) is:  6.629013561145172
# Iteration  92 : x-value is:  2.3728058462847357 f(x) is:  6.621069026270778
# Iteration  93 : x-value is:  2.3700401566562084 f(x) is:  6.61351489679269
# Iteration  94 : x-value is:  2.367343051036747 f(x) is:  6.606330390911541
# Iteration  95 : x-value is:  2.364712542234276 f(x) is:  6.599495944382866
# Iteration  96 : x-value is:  2.362146713847417 f(x) is:  6.592993131219416
# Iteration  97 : x-value is:  2.3596437171288405 f(x) is:  6.586804590147821
# Iteration  98 : x-value is:  2.357201768017173 f(x) is:  6.580913956356287
# Iteration  99 : x-value is:  2.354819144326828 f(x) is:  6.5753057981110175
# Iteration  100 : x-value is:  2.3524941830859123 f(x) is:  6.569965557856026
# Iteration  101 : x-value is:  2.350225278013052 f(x) is:  6.564879497444945
# Iteration  102 : x-value is:  2.34801087712463 f(x) is:  6.560034647183407
# Iteration  103 : x-value is:  2.345849480464525 f(x) is:  6.555418758388271
# Iteration  104 : x-value is:  2.343739637948993 f(x) is:  6.551020259195038
# Iteration  105 : x-value is:  2.3416799473198298 f(x) is:  6.546828213367057
# Iteration  106 : x-value is:  2.339669052199428 f(x) is:  6.54283228188093
# Iteration  107 : x-value is:  2.33770564024177 f(x) is:  6.539022687081207
# Iteration  108 : x-value is:  2.3357884413737957 f(x) is:  6.535390179214286
# Iteration  109 : x-value is:  2.3339162261219557 f(x) is:  6.531926005166881
# Iteration  110 : x-value is:  2.332087804019098 f(x) is:  6.5286218792488135
# Iteration  111 : x-value is:  2.3303020220871553 f(x) is:  6.5254699558722855
# Iteration  112 : x-value is:  2.3285577633913923 f(x) is:  6.522462803991811
# Iteration  113 : x-value is:  2.3268539456622404 f(x) is:  6.5195933831796715
# Iteration  114 : x-value is:  2.3251895199810066 f(x) is:  6.516855021221335
# Iteration  115 : x-value is:  2.3235634695259697 f(x) is:  6.514241393124511
# Iteration  116 : x-value is:  2.3219748083755993 f(x) is:  6.511746501443486
# Iteration  117 : x-value is:  2.320422580365833 f(x) is:  6.509364657827984
# Iteration  118 : x-value is:  2.3189058579985384 f(x) is:  6.507090465712672
# Iteration  119 : x-value is:  2.3174237413984566 f(x) is:  6.504918804069678
# Iteration  120 : x-value is:  2.315975357316093 f(x) is:  6.502844812152436
# Iteration  121 : x-value is:  2.31455985817417 f(x) is:  6.50086387516421
# Iteration  122 : x-value is:  2.313176421155395 f(x) is:  6.498971610789923
# Iteration  123 : x-value is:  2.3118242473294393 f(x) is:  6.4971638565339696
# Iteration  124 : x-value is:  2.3105025608171363 f(x) is:  6.495436657811318
# Iteration  125 : x-value is:  2.309210607990028 f(x) is:  6.493786256742528
# Iteration  126 : x-value is:  2.3079476567034978 f(x) is:  6.492209081607211
# Iteration  127 : x-value is:  2.306712995561826 f(x) is:  6.490701736913479
# Iteration  128 : x-value is:  2.3055059332136 f(x) is:  6.489260994044031
# Iteration  129 : x-value is:  2.304325797675997 f(x) is:  6.487883782442175
# Iteration  130 : x-value is:  2.30317193568655 f(x) is:  6.486567181303734
# Iteration  131 : x-value is:  2.3020437120810637 f(x) is:  6.485308411743123
# Iteration  132 : x-value is:  2.300940509196451 f(x) is:  6.484104829403957
# Iteration  133 : x-value is:  2.299861726297295 f(x) is:  6.482953917486718
# Iteration  134 : x-value is:  2.2988067790250364 f(x) is:  6.481853280167758
# Iteration  135 : x-value is:  2.29777509886872 f(x) is:  6.48080063638573
# Iteration  136 : x-value is:  2.2967661326563116 f(x) is:  6.479793813973007
# Iteration  137 : x-value is:  2.2957793420656354 f(x) is:  6.4788307441113595
# Iteration  138 : x-value is:  2.2948142031540395 f(x) is:  6.477909456092238
# Iteration  139 : x-value is:  2.2938702059059404 f(x) is:  6.477028072363581
# Iteration  140 : x-value is:  2.292946853797443 f(x) is:  6.476184803846067
# Iteration  141 : x-value is:  2.2920436633772763 f(x) is:  6.475377945502867
# Iteration  142 : x-value is:  2.2911601638633154 f(x) is:  6.474605872148075
# Iteration  143 : x-value is:  2.2902958967540137 f(x) is:  6.473867034479728
# Iteration  144 : x-value is:  2.2894504154540836 f(x) is:  6.473159955324611
# Iteration  145 : x-value is:  2.2886232849138137 f(x) is:  6.472483226082282
# Iteration  146 : x-value is:  2.287814081281435 f(x) is:  6.4718355033571555
# Iteration  147 : x-value is:  2.287022391567972 f(x) is:  6.471215505767727
# Iteration  148 : x-value is:  2.286247813324056 f(x) is:  6.470622010922899
# Iteration  149 : x-value is:  2.2854899543281864 f(x) is:  6.470053852555981
# Iteration  150 : x-value is:  2.2847484322859706 f(x) is:  6.469509917807446
# Iteration  151 : x-value is:  2.2840228745398745 f(x) is:  6.468989144648155
# Iteration  152 : x-value is:  2.2833129177890576 f(x) is:  6.468490519435175
# Iteration  153 : x-value is:  2.2826182078188726 f(x) is:  6.468013074592882
# Iteration  154 : x-value is:  2.2819383992396367 f(x) is:  6.467555886412406
# Iteration  155 : x-value is:  2.2812731552343 f(x) is:  6.467118072962926
# Iteration  156 : x-value is:  2.280622147314652 f(x) is:  6.466698792108701
# Iteration  157 : x-value is:  2.2799850550857212 f(x) is:  6.46629723962613
# Iteration  158 : x-value is:  2.2793615660180473 f(x) is:  6.465912647415333
# Iteration  159 : x-value is:  2.278751375227512 f(x) is:  6.46554428180125
# Iteration  160 : x-value is:  2.2781541852624314 f(x) is:  6.46519144191938
# Iteration  161 : x-value is:  2.2775697058976294 f(x) is:  6.464853458181761
# Iteration  162 : x-value is:  2.2769976539352177 f(x) is:  6.46452969081874
# Iteration  163 : x-value is:  2.276437753011827 f(x) is:  6.464219528492698
# Iteration  164 : x-value is:  2.2758897334120443 f(x) is:  6.4639223869798705
# Iteration  165 : x-value is:  2.275353331887814 f(x) is:  6.463637707916643
# Iteration  166 : x-value is:  2.2748282914835865 f(x) is:  6.463364957607002
# Iteration  167 : x-value is:  2.2743143613669887 f(x) is:  6.463103625887996
# Iteration  168 : x-value is:  2.2738112966648196 f(x) is:  6.462853225050154
# Iteration  169 : x-value is:  2.2733188583041666 f(x) is:  6.462613288809983
# Iteration  170 : x-value is:  2.272836812858457 f(x) is:  6.462383371331949
# Iteration  171 : x-value is:  2.272364932398265 f(x) is:  6.462163046297391
# Iteration  172 : x-value is:  2.2719029943466986 f(x) is:  6.461951906017941
# Iteration  173 : x-value is:  2.271450781339202 f(x) is:  6.461749560591208
# Iteration  174 : x-value is:  2.271008081087613 f(x) is:  6.461555637096598
# Iteration  175 : x-value is:  2.2705746862483296 f(x) is:  6.461369778829258
# Iteration  176 : x-value is:  2.2701503942944283 f(x) is:  6.461191644570132
# Iteration  177 : x-value is:  2.2697350073916076 f(x) is:  6.461020907890504
# Iteration  178 : x-value is:  2.269328332277812 f(x) is:  6.460857256489149
# Iteration  179 : x-value is:  2.2689301801464152 f(x) is:  6.460700391560497
# Iteration  180 : x-value is:  2.268540366532833 f(x) is:  6.460550027192401
# Iteration  181 : x-value is:  2.268158711204455 f(x) is:  6.460405889791861
# Iteration  182 : x-value is:  2.2677850380537716 f(x) is:  6.46026771753748
# Iteration  183 : x-value is:  2.267419174994599 f(x) is:  6.460135259857243
# Iteration  184 : x-value is:  2.267060953861286 f(x) is:  6.460008276930473
# Iteration  185 : x-value is:  2.266710210310808 f(x) is:  6.459886539212725
# Iteration  186 : x-value is:  2.2663667837276553 f(x) is:  6.459769826982477
# Iteration  187 : x-value is:  2.266030517131411 f(x) is:  6.459657929908698
# Iteration  188 : x-value is:  2.265701257086941 f(x) is:  6.459550646638057
# Iteration  189 : x-value is:  2.265378853617106 f(x) is:  6.459447784401188
# Iteration  190 : x-value is:  2.2650631601179074 f(x) is:  6.459349158636609
# Iteration  191 : x-value is:  2.2647540332759992 f(x) is:  6.45925459263195
# Iteration  192 : x-value is:  2.2644513329884774 f(x) is:  6.459163917181328
# Iteration  193 : x-value is:  2.2641549222848836 f(x) is:  6.459076970258245
# Iteration  194 : x-value is:  2.2638646672513425 f(x) is:  6.4589935967032055
# Iteration  195 : x-value is:  2.2635804369567745 f(x) is:  6.458913647925446
# Iteration  196 : x-value is:  2.263302103381111 f(x) is:  6.458836981618049
# Iteration  197 : x-value is:  2.2630295413454515 f(x) is:  6.458763461485816
# Iteration  198 : x-value is:  2.262762628444102 f(x) is:  6.458692956985306
# Iteration  199 : x-value is:  2.2625012449784356 f(x) is:  6.458625343076498
# Iteration  200 : x-value is:  2.2622452738925194 f(x) is:  6.458560499985502
# Iteration  201 : x-value is:  2.261994600710452 f(x) is:  6.458498312977849
# Iteration  202 : x-value is:  2.26174911347536 f(x) is:  6.458438672141792
# Iteration  203 : x-value is:  2.2615087026900005 f(x) is:  6.458381472181266
# Iteration  204 : x-value is:  2.2612732612589292 f(x) is:  6.458326612217952
# Iteration  205 : x-value is:  2.261042684432173 f(x) is:  6.458273995602109
# Iteration  206 : x-value is:  2.2608168697503723 f(x) is:  6.45822352973169
# Iteration  207 : x-value is:  2.2605957169913484 f(x) is:  6.458175125879503
# Iteration  208 : x-value is:  2.260379128118048 f(x) is:  6.458128699027871
# Iteration  209 : x-value is:  2.2601670072278286 f(x) is:  6.45808416771057
# Iteration  210 : x-value is:  2.2599592605030434 f(x) is:  6.458041453861682
# Iteration  211 : x-value is:  2.2597557961628896 f(x) is:  6.458000482671061
# Iteration  212 : x-value is:  2.25955652441648 f(x) is:  6.457961182446084
# Iteration  213 : x-value is:  2.2593613574171045 f(x) is:  6.457923484479451
# Iteration  214 : x-value is:  2.259170209217649 f(x) is:  6.4578873229226375
# Iteration  215 : x-value is:  2.258982995727132 f(x) is:  6.457852634665006
# Iteration  216 : x-value is:  2.258799634668334 f(x) is:  6.457819359217986
# Iteration  217 : x-value is:  2.2586200455364867 f(x) is:  6.457787438604374
# Iteration  218 : x-value is:  2.2584441495589855 f(x) is:  6.457756817252385
# Iteration  219 : x-value is:  2.258271869656109 f(x) is:  6.457727441894242
# Iteration  220 : x-value is:  2.258103130402704 f(x) is:  6.457699261469227
# Iteration  221 : x-value is:  2.2579378579908176 f(x) is:  6.457672227030752
# Iteration  222 : x-value is:  2.257775980193248 f(x) is:  6.457646291657628
# Iteration  223 : x-value is:  2.2576174263279856 f(x) is:  6.457621410368905
# Iteration  224 : x-value is:  2.257462127223524 f(x) is:  6.457597540042599
# Iteration  225 : x-value is:  2.2573100151850145 f(x) is:  6.457574639337697
# Iteration  226 : x-value is:  2.2571610239612405 f(x) is:  6.457552668619623
# Iteration  227 : x-value is:  2.2570150887123934 f(x) is:  6.457531589888852
# Iteration  228 : x-value is:  2.2568721459786225 f(x) is:  6.457511366712534
# Iteration  229 : x-value is:  2.2567321336493427 f(x) is:  6.457491964159075
# Iteration  230 : x-value is:  2.256594990933276 f(x) is:  6.457473348735466
# Iteration  231 : x-value is:  2.256460658329212 f(x) is:  6.457455488327341
# Iteration  232 : x-value is:  2.2563290775974627 f(x) is:  6.457438352141477
# Iteration  233 : x-value is:  2.256200191731995 f(x) is:  6.457421910650805
# Iteration  234 : x-value is:  2.2560739449332265 f(x) is:  6.457406135541749
# Iteration  235 : x-value is:  2.255950282581462 f(x) is:  6.4573909996637475
# Iteration  236 : x-value is:  2.2558291512109574 f(x) is:  6.457376476980965
# Iteration  237 : x-value is:  2.2557104984845915 f(x) is:  6.457362542525978
# Iteration  238 : x-value is:  2.255594273169133 f(x) is:  6.457349172355503
# Iteration  239 : x-value is:  2.255480425111086 f(x) is:  6.4573363435078726
# Iteration  240 : x-value is:  2.2553689052130976 f(x) is:  6.457324033962429
# Iteration  241 : x-value is:  2.255259665410917 f(x) is:  6.4573122226005175
# Iteration  242 : x-value is:  2.2551526586508865 f(x) is:  6.457300889168177
# Iteration  243 : x-value is:  2.255047838867955 f(x) is:  6.45729001424041
# Iteration  244 : x-value is:  2.254945160964199 f(x) is:  6.457279579186871
# Iteration  245 : x-value is:  2.254844580787841 f(x) is:  6.457269566139111
# Iteration  246 : x-value is:  2.2547460551127445 f(x) is:  6.457259957959064
# Iteration  247 : x-value is:  2.2546495416183867 f(x) is:  6.457250738208977
# Iteration  248 : x-value is:  2.254554998870284 f(x) is:  6.457241891122504
# Iteration  249 : x-value is:  2.254462386300867 f(x) is:  6.4572334015770245
# Iteration  250 : x-value is:  2.2543716641907916 f(x) is:  6.457225255067186
# Iteration  251 : x-value is:  2.254282793650672 f(x) is:  6.457217437679436
# Iteration  252 : x-value is:  2.2541957366032346 f(x) is:  6.457209936067706
# Iteration  253 : x-value is:  2.254110455765867 f(x) is:  6.457202737430109
# Iteration  254 : x-value is:  2.2540269146335707 f(x) is:  6.457195829486494
# Iteration  255 : x-value is:  2.253945077462292 f(x) is:  6.457189200457087
# Iteration  256 : x-value is:  2.25386490925263 f(x) is:  6.457182839041916
# Iteration  257 : x-value is:  2.2537863757339123 f(x) is:  6.457176734401134
# Iteration  258 : x-value is:  2.2537094433486233 f(x) is:  6.457170876136118
# Iteration  259 : x-value is:  2.2536340792371874 f(x) is:  6.457165254271427
# Iteration  260 : x-value is:  2.2535602512230857 f(x) is:  6.4571598592373896
# Iteration  261 : x-value is:  2.25348792779831 f(x) is:  6.457154681853556
# Iteration  262 : x-value is:  2.2534170781091367 f(x) is:  6.457149713312724
# Iteration  263 : x-value is:  2.2533476719422194 f(x) is:  6.457144945165648
# Iteration  264 : x-value is:  2.2532796797109875 f(x) is:  6.457140369306433
# Iteration  265 : x-value is:  2.253213072442349 f(x) is:  6.457135977958469
# Iteration  266 : x-value is:  2.2531478217636853 f(x) is:  6.45713176366095
# Iteration  267 : x-value is:  2.253083899890133 f(x) is:  6.457127719256032
# Iteration  268 : x-value is:  2.253021279612147 f(x) is:  6.4571238378763915
# Iteration  269 : x-value is:  2.2529599342833375 f(x) is:  6.457120112933403
# Iteration  270 : x-value is:  2.252899837808572 f(x) is:  6.457116538105737
# Iteration  271 : x-value is:  2.252840964632341 f(x) is:  6.457113107328485
# Iteration  272 : x-value is:  2.2527832897273767 f(x) is:  6.4571098147826795
# Iteration  273 : x-value is:  2.252726788583521 f(x) is:  6.457106654885266
# Iteration  274 : x-value is:  2.2526714371968386 f(x) is:  6.457103622279487
# Iteration  275 : x-value is:  2.2526172120589623 f(x) is:  6.45710071182566
# Iteration  276 : x-value is:  2.2525640901466772 f(x) is:  6.457097918592375
# Iteration  277 : x-value is:  2.252512048911727 f(x) is:  6.4570952378479305
# Iteration  278 : x-value is:  2.252461066270841 f(x) is:  6.45709266505229
# Iteration  279 : x-value is:  2.252411120595982 f(x) is:  6.457090195849229
# Iteration  280 : x-value is:  2.2523621907047997 f(x) is:  6.457087826058881
# Iteration  281 : x-value is:  2.2523142558512954 f(x) is:  6.457085551670527
# Iteration  282 : x-value is:  2.2522672957166856 f(x) is:  6.457083368835793
# Iteration  283 : x-value is:  2.2522212904004637 f(x) is:  6.457081273861988
# Iteration  284 : x-value is:  2.252176220411655 f(x) is:  6.457079263205774
# Iteration  285 : x-value is:  2.2521320666602582 f(x) is:  6.457077333467147
# Iteration  286 : x-value is:  2.2520888104488725 f(x) is:  6.457075481383583
# Iteration  287 : x-value is:  2.2520464334645043 f(x) is:  6.457073703824452
# Iteration  288 : x-value is:  2.2520049177705483 f(x) is:  6.457071997785679
# Iteration  289 : x-value is:  2.2519642457989435 f(x) is:  6.457070360384613
# Iteration  290 : x-value is:  2.2519244003424927 f(x) is:  6.457068788855064
# Iteration  291 : x-value is:  2.25188536454735 f(x) is:  6.457067280542624
# Iteration  292 : x-value is:  2.251847121905669 f(x) is:  6.457065832900128
# Iteration  293 : x-value is:  2.2518096562484025 f(x) is:  6.457064443483244
# Iteration  294 : x-value is:  2.2517729517382636 f(x) is:  6.457063109946411
# Iteration  295 : x-value is:  2.25173699286283 f(x) is:  6.457061830038736
# Iteration  296 : x-value is:  2.251701764427799 f(x) is:  6.457060601600215
# Iteration  297 : x-value is:  2.251667251550384 f(x) is:  6.457059422558043
# Iteration  298 : x-value is:  2.2516334396528515 f(x) is:  6.457058290923079
# Iteration  299 : x-value is:  2.2516003144561965 f(x) is:  6.457057204786437
# Iteration  300 : x-value is:  2.2515678619739505 f(x) is:  6.45705616231626
# Iteration  301 : x-value is:  2.2515360685061205 f(x) is:  6.45705516175461
# Iteration  302 : x-value is:  2.251504920633258 f(x) is:  6.457054201414454
# Iteration  303 : x-value is:  2.2514744052106512 f(x) is:  6.4570532796768205
# Iteration  304 : x-value is:  2.2514445093626416 f(x) is:  6.457052394987997
# Iteration  305 : x-value is:  2.2514152204770603 f(x) is:  6.4570515458569595
# Iteration  306 : x-value is:  2.25138652619978 f(x) is:  6.457050730852785
# Iteration  307 : x-value is:  2.251358414429384 f(x) is:  6.457049948602251
# Iteration  308 : x-value is:  2.2513308733119466 f(x) is:  6.457049197787484
# Iteration  309 : x-value is:  2.2513038912359224 f(x) is:  6.4570484771437116
# Iteration  310 : x-value is:  2.2512774568271454 f(x) is:  6.457047785457167
# Iteration  311 : x-value is:  2.25125155894393 f(x) is:  6.457047121562983
# Iteration  312 : x-value is:  2.2512261866722776 f(x) is:  6.457046484343213
# Iteration  313 : x-value is:  2.251201329321182 f(x) is:  6.457045872724976
# Iteration  314 : x-value is:  2.2511769764180345 f(x) is:  6.457045285678596
# Iteration  315 : x-value is:  2.2511531177041246 f(x) is:  6.45704472221589
# Iteration  316 : x-value is:  2.2511297431302353 f(x) is:  6.457044181388454
# Iteration  317 : x-value is:  2.2511068428523284 f(x) is:  6.457043662286104
# Iteration  318 : x-value is:  2.251084407227325 f(x) is:  6.457043164035287
# Iteration  319 : x-value is:  2.2510624268089683 f(x) is:  6.457042685797646
# Iteration  320 : x-value is:  2.251040892343777 f(x) is:  6.457042226768571
# Iteration  321 : x-value is:  2.2510197947670805 f(x) is:  6.457041786175832
# Iteration  322 : x-value is:  2.25099912519914 f(x) is:  6.457041363278293
# Iteration  323 : x-value is:  2.2509788749413473 f(x) is:  6.457040957364665
# Iteration  324 : x-value is:  2.2509590354725026 f(x) is:  6.45704056775228
# Iteration  325 : x-value is:  2.2509395984451737 f(x) is:  6.457040193785936
# Iteration  326 : x-value is:  2.2509205556821263 f(x) is:  6.457039834836802
# Iteration  327 : x-value is:  2.2509018991728333 f(x) is:  6.457039490301348
# Iteration  328 : x-value is:  2.250883621070051 f(x) is:  6.4570391596003525
# Iteration  329 : x-value is:  2.2508657136864714 f(x) is:  6.457038842177866
# Iteration  330 : x-value is:  2.2508481694914417 f(x) is:  6.457038537500313
# Iteration  331 : x-value is:  2.2508309811077525 f(x) is:  6.4570382450555925
# Iteration  332 : x-value is:  2.2508141413084926 f(x) is:  6.45703796435221
# Iteration  333 : x-value is:  2.250797643013968 f(x) is:  6.457037694918405
# Iteration  334 : x-value is:  2.250781479288686 f(x) is:  6.457037436301437
# Iteration  335 : x-value is:  2.2507656433384033 f(x) is:  6.457037188066742
# Iteration  336 : x-value is:  2.25075012850723 f(x) is:  6.457036949797242
# Iteration  337 : x-value is:  2.2507349282748006 f(x) is:  6.457036721092624
# Iteration  338 : x-value is:  2.250720036253496 f(x) is:  6.457036501568684
# Iteration  339 : x-value is:  2.2507054461857297 f(x) is:  6.457036290856653
# Iteration  340 : x-value is:  2.2506911519412864 f(x) is:  6.457036088602607
# Iteration  341 : x-value is:  2.2506771475147165 f(x) is:  6.45703589446682
# Iteration  342 : x-value is:  2.2506634270227837 f(x) is:  6.45703570812325
# Iteration  343 : x-value is:  2.2506499847019668 f(x) is:  6.45703552925896
# Iteration  344 : x-value is:  2.2506368149060116 f(x) is:  6.457035357573563
# Iteration  345 : x-value is:  2.250623912103534 f(x) is:  6.457035192778779
# Iteration  346 : x-value is:  2.2506112708756723 f(x) is:  6.457035034597901
# Iteration  347 : x-value is:  2.2505988859137886 f(x) is:  6.457034882765342
# Iteration  348 : x-value is:  2.250586752017217 f(x) is:  6.457034737026188
# Iteration  349 : x-value is:  2.2505748640910577 f(x) is:  6.457034597135781
# Iteration  350 : x-value is:  2.2505632171440166 f(x) is:  6.457034462859273
# Iteration  351 : x-value is:  2.2505518062862917 f(x) is:  6.457034333971258
# Iteration  352 : x-value is:  2.250540626727499 f(x) is:  6.457034210255408
# Iteration  353 : x-value is:  2.2505296737746447 f(x) is:  6.457034091504056
# Iteration  354 : x-value is:  2.250518942830136 f(x) is:  6.457033977517902
# Iteration  355 : x-value is:  2.250508429389837 f(x) is:  6.45703386810564
# Iteration  356 : x-value is:  2.250498129041159 f(x) is:  6.457033763083658
# Iteration  357 : x-value is:  2.2504880374611953 f(x) is:  6.457033662275709
# Iteration  358 : x-value is:  2.250478150414891 f(x) is:  6.457033565512635
# The local minimum occurs at:  2.250478150414891

# %% [markdown]
# (c) Start the search at $x_0=10$ with the following settings: learning rate $\alpha=0.01$, epsilon =  0.00001, and the maximum number of iterations = 10000.

# %%
x = 10
alpha = 0.01
epsilon = 0.00001
diff = 1
max_iter = 10000
iter = 1

f = lambda x: x**4 - 3*x**3 + 15
deriv = lambda x: 4*x**3 - 9*x**2

while diff > epsilon:
    x_n = x - alpha * deriv(x)
    print("Iteration ", iter, ": x-value is: ", x_n,"f(x) is: ", f(x_n) )
    diff = abs(x_n-x)
    iter += 1
    x = x_n
    
print("The local minimum occurs at: ", x)
# Out:
# Iteration  1 : x-value is:  -21.0 f(x) is:  222279.0
# Iteration  2 : x-value is:  389.13 f(x) is:  22751900903.504723
# Iteration  3 : x-value is:  -2342899.03245888 f(x) is:  3.013109038267281e+25
# Iteration  4 : x-value is:  5.144238880063777e+17 f(x) is:  7.003006184304912e+70
# Iteration  5 : x-value is:  -5.44531958766121e+51 f(x) is:  8.792117731840386e+206
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-42-29fe9745670a> in <module>
#      11 while diff > epsilon:
#      12     x_n = x - alpha * deriv(x)
# ---> 13     print("Iteration ", iter, ": x-value is: ", x_n,"f(x) is: ", f(x_n) )
#      14     diff = abs(x_n-x)
#      15     iter += 1
#
# <ipython-input-42-29fe9745670a> in <lambda>(x)
#       6 iter = 1
#       7
# ----> 8 f = lambda x: x**4 - 3*x**3 + 15
#       9 deriv = lambda x: 4*x**3 - 9*x**2
#      10
#
# OverflowError: (34, 'Result too large')

# %% [markdown]
# (d) Start the search at $x_0=-2$ with the following settings: learning rate $\alpha=0.01$, epsilon =  0.00001, and the maximum number of iterations = 10000.

# %%
x = -2
alpha = 0.01
epsilon = 0.00001
diff = 1
max_iter = 10000
iter = 1

f = lambda x: x**4 - 3*x**3 + 15
deriv = lambda x: 4*x**3 - 9*x**2

while diff > epsilon:
    x_n = x - alpha * deriv(x)
    print("Iteration ", iter, ": x-value is: ", x_n,"f(x) is: ", f(x_n) )
    diff = abs(x_n-x)
    iter += 1
    x = x_n
    
print("The local minimum occurs at: ", x)
# Out:
# Iteration  1 : x-value is:  -1.3199999999999998 f(x) is:  24.935861759999995
# Iteration  2 : x-value is:  -1.07118528 f(x) is:  20.00396952146095
# Iteration  3 : x-value is:  -0.9187511249290652 f(x) is:  18.039074415074225
# Iteration  4 : x-value is:  -0.8117609519002669 f(x) is:  17.038966670258308
# Iteration  5 : x-value is:  -0.7310583411316325 f(x) is:  16.457767118015976
# Iteration  6 : x-value is:  -0.6673297173335682 f(x) is:  16.089861605413784
# Iteration  7 : x-value is:  -0.6153628619496416 f(x) is:  15.84245311353719
# Iteration  8 : x-value is:  -0.5719616173472483 f(x) is:  15.668355367484862
# Iteration  9 : x-value is:  -0.5350345460542479 f(x) is:  15.541426035121475
# Iteration  10 : x-value is:  -0.5031445675318701 f(x) is:  15.44620704611241
# Iteration  11 : x-value is:  -0.4752657349385236 f(x) is:  15.373076188447456
# Iteration  12 : x-value is:  -0.45064268444665523 f(x) is:  15.315788976832161
# Iteration  13 : x-value is:  -0.42870495028556926 f(x) is:  15.270150396670067
# Iteration  14 : x-value is:  -0.40901240429843705 f(x) is:  15.233258790418486
# Iteration  15 : x-value is:  -0.39121923491217264 f(x) is:  15.203056298465459
# Iteration  16 : x-value is:  -0.3750494277154039 f(x) is:  15.178051509043394
# Iteration  17 : x-value is:  -0.3602796319220935 f(x) is:  15.15714282295111
# Iteration  18 : x-value is:  -0.34672691252157245 f(x) is:  15.139502802781488
# Iteration  19 : x-value is:  -0.33423981869182634 f(x) is:  15.124500585795179
# Iteration  20 : x-value is:  -0.3226917547645521 f(x) is:  15.111648697225768
# Iteration  21 : x-value is:  -0.3119759822996253 f(x) is:  15.100565880683602
# Iteration  22 : x-value is:  -0.3020017984976482 f(x) is:  15.090950668046634
# Iteration  23 : x-value is:  -0.2926915767272862 f(x) is:  15.08256228903921
# Iteration  24 : x-value is:  -0.283978448125573 f(x) is:  15.075206684460955
# Iteration  25 : x-value is:  -0.2758044662343191 f(x) is:  15.06872612451277
# Iteration  26 : x-value is:  -0.2681191400024105 f(x) is:  15.062991410563962
# Iteration  27 : x-value is:  -0.260878250821262 f(x) is:  15.057895952831313
# Iteration  28 : x-value is:  -0.25404289080053816 f(x) is:  15.053351226876961
# Iteration  29 : x-value is:  -0.24757867499435038 f(x) is:  15.049283255011527
# Iteration  30 : x-value is:  -0.2414550915872042 f(x) is:  15.045629857513525
# Iteration  31 : x-value is:  -0.2356449623801187 f(x) is:  15.042338487697847
# Iteration  32 : x-value is:  -0.2301239921265961 f(x) is:  15.039364513811764
# Iteration  33 : x-value is:  -0.22487038994247116 f(x) is:  15.03666984579593
# Iteration  34 : x-value is:  -0.21986454956553192 f(x) is:  15.03422183033082
# Iteration  35 : x-value is:  -0.21508877796338977 f(x) is:  15.031992356151383
# Iteration  36 : x-value is:  -0.21052706389213488 f(x) is:  15.029957125315933
# Iteration  37 : x-value is:  -0.20616487964689925 f(x) is:  15.028095056320899
# Iteration  38 : x-value is:  -0.20198901053079205 f(x) is:  15.02638779261765
# Iteration  39 : x-value is:  -0.19798740758381211 f(x) is:  15.02481929588902
# Iteration  40 : x-value is:  -0.19414905992025644 f(x) is:  15.023375507867305
# Iteration  41 : x-value is:  -0.19046388366845712 f(x) is:  15.0220440678729
# Iteration  42 : x-value is:  -0.1869226250257383 f(x) is:  15.020814075879397
# Iteration  43 : x-value is:  -0.18351677536128194 f(x) is:  15.01967589295441
# Iteration  44 : x-value is:  -0.18023849664087568 f(x) is:  15.018620972524833
# Iteration  45 : x-value is:  -0.17708055572634868 f(x) is:  15.017641717174325
# Iteration  46 : x-value is:  -0.1740362663313828 f(x) is:  15.016731356677433
# Iteration  47 : x-value is:  -0.17109943760411356 f(x) is:  15.01588384376763
# Iteration  48 : x-value is:  -0.16826432846321804 f(x) is:  15.01509376477066
# Iteration  49 : x-value is:  -0.16552560694413795 f(x) is:  15.014356262743947
# Iteration  50 : x-value is:  -0.1628783139205623 f(x) is:  15.013666971174054
# Iteration  51 : x-value is:  -0.1603178306571885 f(x) is:  15.013021956617399
# Iteration  52 : x-value is:  -0.15783984972621548 f(x) is:  15.012417668940872
# Iteration  53 : x-value is:  -0.1554403488845203 f(x) is:  15.011850898040677
# Iteration  54 : x-value is:  -0.15311556756307723 f(x) is:  15.01131873609974
# Iteration  55 : x-value is:  -0.1508619856665571 f(x) is:  15.010818544593873
# Iteration  56 : x-value is:  -0.1486763044205582 f(x) is:  15.010347925380719
# Iteration  57 : x-value is:  -0.14655542903768262 f(x) is:  15.009904695308293
# Iteration  58 : x-value is:  -0.144496453002602 f(x) is:  15.009486863865321
# Iteration  59 : x-value is:  -0.14249664380111696 f(x) is:  15.009092613467026
# Iteration  60 : x-value is:  -0.14055342993962955 f(x) is:  15.008720282029707
# Iteration  61 : x-value is:  -0.13866438911994683 f(x) is:  15.008368347537694
# Iteration  62 : x-value is:  -0.1368272374503496 f(x) is:  15.00803541434846
# Iteration  63 : x-value is:  -0.13503981958776168 f(x) is:  15.007720201017468
# Iteration  64 : x-value is:  -0.13330009971794743 f(x) is:  15.007421529454506
# Iteration  65 : x-value is:  -0.13160615329120867 f(x) is:  15.007138315248959
# Iteration  66 : x-value is:  -0.12995615944026376 f(x) is:  15.006869559023352
# Iteration  67 : x-value is:  -0.12834839401505746 f(x) is:  15.00661433869312
# Iteration  68 : x-value is:  -0.12678122317632676 f(x) is:  15.006371802526536
# Iteration  69 : x-value is:  -0.1252530974959679 f(x) is:  15.006141162912412
# Iteration  70 : x-value is:  -0.12376254651772922 f(x) is:  15.005921690754969
# Iteration  71 : x-value is:  -0.12230817373658795 f(x) is:  15.005712710425316
# Iteration  72 : x-value is:  -0.12088865195944345 f(x) is:  15.005513595207841
# Iteration  73 : x-value is:  -0.11950271901354209 f(x) is:  15.005323763187262
# Iteration  74 : x-value is:  -0.11814917377240623 f(x) is:  15.005142673528693
# Iteration  75 : x-value is:  -0.11682687247202156 f(x) is:  15.004969823108764
# Iteration  76 : x-value is:  -0.11553472529269043 f(x) is:  15.004804743460742
# Iteration  77 : x-value is:  -0.11427169318432426 f(x) is:  15.00464699800096
# Iteration  78 : x-value is:  -0.11303678491505899 f(x) is:  15.004496179507571
# Iteration  79 : x-value is:  -0.11182905432496491 f(x) is:  15.004351907825987
# Iteration  80 : x-value is:  -0.11064759776831164 f(x) is:  15.004213827778175
# Iteration  81 : x-value is:  -0.10949155172936369 f(x) is:  15.004081607255609
# Iteration  82 : x-value is:  -0.10836009059804175 f(x) is:  15.003954935477775
# Iteration  83 : x-value is:  -0.1072524245930069 f(x) is:  15.00383352140021
# Iteration  84 : x-value is:  -0.10616779782082526 f(x) is:  15.003717092257668
# Iteration  85 : x-value is:  -0.10510548646086168 f(x) is:  15.003605392229614
# Iteration  86 : x-value is:  -0.10406479706644615 f(x) is:  15.003498181216537
# Iteration  87 : x-value is:  -0.10304506497366427 f(x) is:  15.003395233716788
# Iteration  88 : x-value is:  -0.1020456528098542 f(x) is:  15.003296337794715
# Iteration  89 : x-value is:  -0.10106594909455496 f(x) is:  15.003201294131772
# Iteration  90 : x-value is:  -0.10010536692625006 f(x) is:  15.003109915153146
# Iteration  91 : x-value is:  -0.09916334274879597 f(x) is:  15.003022024223187
# Iteration  92 : x-value is:  -0.09823933519191902 f(x) is:  15.002937454903542
# Iteration  93 : x-value is:  -0.09733282398061464 f(x) is:  15.00285605026856
# Iteration  94 : x-value is:  -0.09644330890869242 f(x) is:  15.002777662272992
# Iteration  95 : x-value is:  -0.0955703088720836 f(x) is:  15.002702151167535
# Iteration  96 : x-value is:  -0.09471336095786868 f(x) is:  15.00262938495814
# Iteration  97 : x-value is:  -0.09387201958529302 f(x) is:  15.002559238905457
# Iteration  98 : x-value is:  -0.09304585569532328 f(x) is:  15.00249159506102
# Iteration  99 : x-value is:  -0.09223445598555699 f(x) is:  15.002426341837229
# Iteration  100 : x-value is:  -0.09143742218753592 f(x) is:  15.002363373608294
# Iteration  101 : x-value is:  -0.09065437038373193 f(x) is:  15.002302590339708
# Iteration  102 : x-value is:  -0.08988493036167403 f(x) is:  15.002243897243922
# Iteration  103 : x-value is:  -0.08912874500286933 f(x) is:  15.002187204460167
# Iteration  104 : x-value is:  -0.08838546970433911 f(x) is:  15.002132426756527
# Iteration  105 : x-value is:  -0.08765477183074655 f(x) is:  15.002079483252514
# Iteration  106 : x-value is:  -0.08693633019523538 f(x) is:  15.002028297160598
# Iteration  107 : x-value is:  -0.08622983456723049 f(x) is:  15.001978795545192
# Iteration  108 : x-value is:  -0.08553498520557254 f(x) is:  15.001930909097828
# Iteration  109 : x-value is:  -0.08485149241547049 f(x) is:  15.001884571927253
# Iteration  110 : x-value is:  -0.08417907612785942 f(x) is:  15.001839721363377
# Iteration  111 : x-value is:  -0.08351746549984608 f(x) is:  15.001796297774023
# Iteration  112 : x-value is:  -0.08286639853501296 f(x) is:  15.00175424439355
# Iteration  113 : x-value is:  -0.08222562172243315 f(x) is:  15.0017135071625
# Iteration  114 : x-value is:  -0.08159488969332389 f(x) is:  15.001674034577437
# Iteration  115 : x-value is:  -0.0809739648943363 f(x) is:  15.001635777550316
# Iteration  116 : x-value is:  -0.08036261727654409 f(x) is:  15.001598689276623
# Iteration  117 : x-value is:  -0.07976062399925382 f(x) is:  15.001562725111752
# Iteration  118 : x-value is:  -0.07916776914781518 f(x) is:  15.00152784245498
# Iteration  119 : x-value is:  -0.07858384346466166 f(x) is:  15.00149400064056
# Iteration  120 : x-value is:  -0.07800864409286018 f(x) is:  15.001461160835419
# Iteration  121 : x-value is:  -0.07744197433149287 f(x) is:  15.00142928594301
# Iteration  122 : x-value is:  -0.076883643402236 f(x) is:  15.001398340512928
# Iteration  123 : x-value is:  -0.07633346622653994 f(x) is:  15.00136829065588
# Iteration  124 : x-value is:  -0.07579126321285001 f(x) is:  15.001339103963643
# Iteration  125 : x-value is:  -0.07525686005334183 f(x) is:  15.00131074943373
# Iteration  126 : x-value is:  -0.07473008752967622 f(x) is:  15.001283197398392
# Iteration  127 : x-value is:  -0.0742107813273082 f(x) is:  15.001256419457725
# Iteration  128 : x-value is:  -0.07369878185791148 f(x) is:  15.001230388416593
# Iteration  129 : x-value is:  -0.07319393408950618 f(x) is:  15.00120507822512
# Iteration  130 : x-value is:  -0.07269608738390058 f(x) is:  15.001180463922546
# Iteration  131 : x-value is:  -0.07220509534108083 f(x) is:  15.001156521584203
# Iteration  132 : x-value is:  -0.07172081565020283 f(x) is:  15.001133228271447
# Iteration  133 : x-value is:  -0.07124310994686053 f(x) is:  15.00111056198434
# Iteration  134 : x-value is:  -0.07077184367632286 f(x) is:  15.001088501616925
# Iteration  135 : x-value is:  -0.0703068859624489 f(x) is:  15.00106702691492
# Iteration  136 : x-value is:  -0.06984810948200702 f(x) is:  15.001046118435712
# Iteration  137 : x-value is:  -0.0693953903441387 f(x) is:  15.001025757510467
# Iteration  138 : x-value is:  -0.06894860797472181 f(x) is:  15.001005926208288
# Iteration  139 : x-value is:  -0.06850764500540181 f(x) is:  15.000986607302234
# Iteration  140 : x-value is:  -0.06807238716707142 f(x) is:  15.00096778423715
# Iteration  141 : x-value is:  -0.06764272318759126 f(x) is:  15.000949441099143
# Iteration  142 : x-value is:  -0.06721854469355493 f(x) is:  15.00093156258668
# Iteration  143 : x-value is:  -0.0667997461159124 f(x) is:  15.000914133983123
# Iteration  144 : x-value is:  -0.06638622459927536 f(x) is:  15.00089714113071
# Iteration  145 : x-value is:  -0.06597787991473725 f(x) is:  15.00088057040583
# Iteration  146 : x-value is:  -0.0655746143760495 f(x) is:  15.00086440869555
# Iteration  147 : x-value is:  -0.06517633275900356 f(x) is:  15.000848643375331
# Iteration  148 : x-value is:  -0.06478294222387604 f(x) is:  15.000833262287838
# Iteration  149 : x-value is:  -0.0643943522408014 f(x) is:  15.000818253722795
# Iteration  150 : x-value is:  -0.06401047451794366 f(x) is:  15.000803606397854
# Iteration  151 : x-value is:  -0.06363122293234483 f(x) is:  15.000789309440368
# Iteration  152 : x-value is:  -0.06325651346333398 f(x) is:  15.000775352370068
# Iteration  153 : x-value is:  -0.06288626412838658 f(x) is:  15.000761725082572
# Iteration  154 : x-value is:  -0.06252039492132908 f(x) is:  15.00074841783368
# Iteration  155 : x-value is:  -0.06215882775278901 f(x) is:  15.000735421224421
# Iteration  156 : x-value is:  -0.06180148639279552 f(x) is:  15.000722726186801
# Iteration  157 : x-value is:  -0.06144829641543994 f(x) is:  15.000710323970237
# Iteration  158 : x-value is:  -0.06109918514551035 f(x) is:  15.000698206128607
# Iteration  159 : x-value is:  -0.060754081607018146 f(x) is:  15.000686364507914
# Iteration  160 : x-value is:  -0.0604129164735385 f(x) is:  15.000674791234516
# Iteration  161 : x-value is:  -0.06007562202029025 f(x) is:  15.0006634787039
# Iteration  162 : x-value is:  -0.05974213207788439 f(x) is:  15.000652419569965
# Iteration  163 : x-value is:  -0.059412381987673374 f(x) is:  15.000641606734789
# Iteration  164 : x-value is:  -0.05908630855863685 f(x) is:  15.000631033338868
# Iteration  165 : x-value is:  -0.05876385002574214 f(x) is:  15.000620692751783
# Iteration  166 : x-value is:  -0.058444946009720826 f(x) is:  15.000610578563291
# Iteration  167 : x-value is:  -0.05812953747820535 f(x) is:  15.000600684574806
# Iteration  168 : x-value is:  -0.05781756670817199 f(x) is:  15.000591004791254
# Iteration  169 : x-value is:  -0.05750897724963918 f(x) is:  15.00058153341329
# Iteration  170 : x-value is:  -0.05720371389057232 f(x) is:  15.000572264829866
# Iteration  171 : x-value is:  -0.05690172262294826 f(x) is:  15.000563193611088
# Iteration  172 : x-value is:  -0.056602950609934935 f(x) is:  15.000554314501416
# Iteration  173 : x-value is:  -0.05630734615414352 f(x) is:  15.000545622413139
# Iteration  174 : x-value is:  -0.05601485866691212 f(x) is:  15.000537112420131
# Iteration  175 : x-value is:  -0.05572543863858215 f(x) is:  15.000528779751871
# Iteration  176 : x-value is:  -0.055439037609729874 f(x) is:  15.000520619787714
# Iteration  177 : x-value is:  -0.05515560814331757 f(x) is:  15.000512628051414
# Iteration  178 : x-value is:  -0.0548751037977298 f(x) is:  15.000504800205857
# Iteration  179 : x-value is:  -0.0545974791006623 f(x) is:  15.000497132048023
# Iteration  180 : x-value is:  -0.05432268952383192 f(x) is:  15.000489619504167
# Iteration  181 : x-value is:  -0.054050691458477594 f(x) is:  15.00048225862517
# Iteration  182 : x-value is:  -0.053781442191623514 f(x) is:  15.00047504558211
# Iteration  183 : x-value is:  -0.053514899883076936 f(x) is:  15.000467976661994
# Iteration  184 : x-value is:  -0.05325102354313407 f(x) is:  15.000461048263665
# Iteration  185 : x-value is:  -0.05298977301096868 f(x) is:  15.000454256893885
# Iteration  186 : x-value is:  -0.052731108933679126 f(x) is:  15.000447599163563
# Iteration  187 : x-value is:  -0.052474992745970325 f(x) is:  15.000441071784131
# Iteration  188 : x-value is:  -0.05222138665044837 f(x) is:  15.000434671564083
# Iteration  189 : x-value is:  -0.05197025359850622 f(x) is:  15.000428395405626
# Iteration  190 : x-value is:  -0.0517215572717798 f(x) is:  15.000422240301475
# Iteration  191 : x-value is:  -0.051475262064154745 f(x) is:  15.00041620333178
# Iteration  192 : x-value is:  -0.05123133306430464 f(x) is:  15.000410281661154
# Iteration  193 : x-value is:  -0.050989736038742586 f(x) is:  15.000404472535827
# Iteration  194 : x-value is:  -0.05075043741536842 f(x) is:  15.00039877328092
# Iteration  195 : x-value is:  -0.050513404267494774 f(x) is:  15.000393181297795
# Iteration  196 : x-value is:  -0.050278604298335645 f(x) is:  15.000387694061533
# Iteration  197 : x-value is:  -0.05004600582594203 f(x) is:  15.000382309118498
# Iteration  198 : x-value is:  -0.049815577768569416 f(x) is:  15.000377024083981
# Iteration  199 : x-value is:  -0.04958728963046291 f(x) is:  15.00037183663996
# Iteration  200 : x-value is:  -0.049361111488045964 f(x) is:  15.000366744532911
# Iteration  201 : x-value is:  -0.04913701397649941 f(x) is:  15.000361745571727
# Iteration  202 : x-value is:  -0.04891496827671797 f(x) is:  15.000356837625702
# Iteration  203 : x-value is:  -0.04869494610263185 f(x) is:  15.000352018622587
# Iteration  204 : x-value is:  -0.048476919688881494 f(x) is:  15.00034728654672
# Iteration  205 : x-value is:  -0.04826086177883408 f(x) is:  15.000342639437235
# Iteration  206 : x-value is:  -0.04804674561293072 f(x) is:  15.000338075386312
# Iteration  207 : x-value is:  -0.047834544917353665 f(x) is:  15.000333592537519
# Iteration  208 : x-value is:  -0.04762423389300335 f(x) is:  15.000329189084185
# Iteration  209 : x-value is:  -0.047415787204775385 f(x) is:  15.00032486326786
# Iteration  210 : x-value is:  -0.04720917997112798 f(x) is:  15.0003206133768
# Iteration  211 : x-value is:  -0.047004387753930635 f(x) is:  15.000316437744534
# Iteration  212 : x-value is:  -0.04680138654858527 f(x) is:  15.000312334748463
# Iteration  213 : x-value is:  -0.04660015277441126 f(x) is:  15.000308302808513
# Iteration  214 : x-value is:  -0.04640066326528621 f(x) is:  15.000304340385837
# Iteration  215 : x-value is:  -0.04620289526053446 f(x) is:  15.000300445981566
# Iteration  216 : x-value is:  -0.04600682639605577 f(x) is:  15.000296618135588
# Iteration  217 : x-value is:  -0.04581243469568673 f(x) is:  15.000292855425393
# Iteration  218 : x-value is:  -0.04561969856278785 f(x) is:  15.000289156464934
# Iteration  219 : x-value is:  -0.04542859677204944 f(x) is:  15.000285519903542
# Iteration  220 : x-value is:  -0.045239108461509574 f(x) is:  15.000281944424877
# Iteration  221 : x-value is:  -0.04505121312477788 f(x) is:  15.000278428745904
# Iteration  222 : x-value is:  -0.04486489060345888 f(x) is:  15.000274971615916
# Iteration  223 : x-value is:  -0.044680121079768896 f(x) is:  15.00027157181558
# Iteration  224 : x-value is:  -0.044496885069340866 f(x) is:  15.000268228156026
# Iteration  225 : x-value is:  -0.04431516341421136 f(x) is:  15.000264939477956
# Iteration  226 : x-value is:  -0.04413493727598452 f(x) is:  15.000261704650788
# Iteration  227 : x-value is:  -0.043956188129167725 f(x) is:  15.000258522571825
# Iteration  228 : x-value is:  -0.043778897754673855 f(x) is:  15.000255392165455
# Iteration  229 : x-value is:  -0.04360304823348542 f(x) is:  15.000252312382376
# Iteration  230 : x-value is:  -0.04342862194047576 f(x) is:  15.000249282198846
# Iteration  231 : x-value is:  -0.04325560153838289 f(x) is:  15.000246300615956
# Iteration  232 : x-value is:  -0.04308396997193146 f(x) is:  15.000243366658927
# Iteration  233 : x-value is:  -0.042913710462098666 f(x) is:  15.000240479376435
# Iteration  234 : x-value is:  -0.04274480650052004 f(x) is:  15.000237637839948
# Iteration  235 : x-value is:  -0.04257724184403104 f(x) is:  15.000234841143095
# Iteration  236 : x-value is:  -0.04241100050934071 f(x) is:  15.000232088401042
# Iteration  237 : x-value is:  -0.04224606676783358 f(x) is:  15.000229378749905
# Iteration  238 : x-value is:  -0.042082425140496274 f(x) is:  15.000226711346162
# Iteration  239 : x-value is:  -0.041920060392965364 f(x) is:  15.000224085366103
# Iteration  240 : x-value is:  -0.04175895753069301 f(x) is:  15.000221500005278
# Iteration  241 : x-value is:  -0.04159910179422717 f(x) is:  15.000218954477981
# Iteration  242 : x-value is:  -0.041440478654603236 f(x) is:  15.000216448016737
# Iteration  243 : x-value is:  -0.04128307380884399 f(x) is:  15.000213979871807
# Iteration  244 : x-value is:  -0.041126873175564925 f(x) is:  15.000211549310713
# Iteration  245 : x-value is:  -0.04097186289068208 f(x) is:  15.000209155617773
# Iteration  246 : x-value is:  -0.04081802930321956 f(x) is:  15.000206798093656
# Iteration  247 : x-value is:  -0.04066535897121407 f(x) is:  15.000204476054941
# Iteration  248 : x-value is:  -0.04051383865771387 f(x) is:  15.0002021888337
# Iteration  249 : x-value is:  -0.040363455326869545 f(x) is:  15.000199935777085
# Iteration  250 : x-value is:  -0.0402141961401142 f(x) is:  15.000197716246928
# Iteration  251 : x-value is:  -0.04006604845243067 f(x) is:  15.000195529619372
# Iteration  252 : x-value is:  -0.03991899980870344 f(x) is:  15.000193375284475
# Iteration  253 : x-value is:  -0.03977303794015302 f(x) is:  15.000191252645863
# Iteration  254 : x-value is:  -0.03962815076085064 f(x) is:  15.000189161120373
# Iteration  255 : x-value is:  -0.039484326364311075 f(x) is:  15.000187100137715
# Iteration  256 : x-value is:  -0.039341553020161686 f(x) is:  15.000185069140139
# Iteration  257 : x-value is:  -0.03919981917088559 f(x) is:  15.000183067582109
# Iteration  258 : x-value is:  -0.039059113428637035 f(x) is:  15.000181094929998
# Iteration  259 : x-value is:  -0.038919424572127194 f(x) is:  15.000179150661783
# Iteration  260 : x-value is:  -0.03878074154357849 f(x) is:  15.00017723426675
# Iteration  261 : x-value is:  -0.03864305344574571 f(x) is:  15.00017534524521
# Iteration  262 : x-value is:  -0.038506349539002234 f(x) is:  15.000173483108217
# Iteration  263 : x-value is:  -0.038370619238489674 f(x) is:  15.000171647377302
# Iteration  264 : x-value is:  -0.03823585211132935 f(x) is:  15.000169837584215
# Iteration  265 : x-value is:  -0.03810203787389401 f(x) is:  15.000168053270665
# Iteration  266 : x-value is:  -0.03796916638913832 f(x) is:  15.000166293988073
# Iteration  267 : x-value is:  -0.03783722766398659 f(x) is:  15.000164559297339
# Iteration  268 : x-value is:  -0.03770621184677637 f(x) is:  15.000162848768596
# Iteration  269 : x-value is:  -0.037576109224756446 f(x) is:  15.000161161981
# Iteration  270 : x-value is:  -0.03744691022163799 f(x) is:  15.000159498522493
# Iteration  271 : x-value is:  -0.03731860539519745 f(x) is:  15.000157857989599
# Iteration  272 : x-value is:  -0.03719118543492992 f(x) is:  15.000156239987216
# Iteration  273 : x-value is:  -0.03706464115975185 f(x) is:  15.00015464412841
# Iteration  274 : x-value is:  -0.03693896351575177 f(x) is:  15.000153070034214
# Iteration  275 : x-value is:  -0.03681414357398787 f(x) is:  15.000151517333446
# Iteration  276 : x-value is:  -0.036690172528331386 f(x) is:  15.00014998566252
# Iteration  277 : x-value is:  -0.036567041693354604 f(x) is:  15.000148474665254
# Iteration  278 : x-value is:  -0.03644474250226242 f(x) is:  15.000146983992712
# Iteration  279 : x-value is:  -0.03632326650486642 f(x) is:  15.000145513303023
# Iteration  280 : x-value is:  -0.036202605365600465 f(x) is:  15.000144062261208
# Iteration  281 : x-value is:  -0.03608275086157678 f(x) is:  15.000142630539033
# Iteration  282 : x-value is:  -0.03596369488068156 f(x) is:  15.000141217814832
# Iteration  283 : x-value is:  -0.03584542941970924 f(x) is:  15.000139823773376
# Iteration  284 : x-value is:  -0.035727946582534385 f(x) is:  15.000138448105698
# Iteration  285 : x-value is:  -0.035611238578320464 f(x) is:  15.000137090508973
# Iteration  286 : x-value is:  -0.03549529771976449 f(x) is:  15.000135750686358
# Iteration  287 : x-value is:  -0.03538011642137682 f(x) is:  15.000134428346856
# Iteration  288 : x-value is:  -0.03526568719779519 f(x) is:  15.00013312320519
# Iteration  289 : x-value is:  -0.03515200266213229 f(x) is:  15.00013183498167
# Iteration  290 : x-value is:  -0.035039055524356 f(x) is:  15.000130563402056
# Iteration  291 : x-value is:  -0.034926838589701636 f(x) is:  15.000129308197447
# Iteration  292 : x-value is:  -0.034815344757115334 f(x) is:  15.000128069104152
# Iteration  293 : x-value is:  -0.03470456701772803 f(x) is:  15.000126845863571
# Iteration  294 : x-value is:  -0.03459449845335921 f(x) is:  15.000125638222089
# Iteration  295 : x-value is:  -0.03448513223504979 f(x) is:  15.000124445930954
# Iteration  296 : x-value is:  -0.03437646162162344 f(x) is:  15.000123268746178
# Iteration  297 : x-value is:  -0.0342684799582758 f(x) is:  15.000122106428417
# Iteration  298 : x-value is:  -0.034161180675190854 f(x) is:  15.000120958742889
# Iteration  299 : x-value is:  -0.03405455728618385 f(x) is:  15.000119825459246
# Iteration  300 : x-value is:  -0.03394860338737028 f(x) is:  15.000118706351502
# Iteration  301 : x-value is:  -0.033843312655860276 f(x) is:  15.00011760119792
# Iteration  302 : x-value is:  -0.03373867884847775 f(x) is:  15.000116509780922
# Iteration  303 : x-value is:  -0.033634695800503954 f(x) is:  15.000115431887005
# Iteration  304 : x-value is:  -0.033531357424444734 f(x) is:  15.000114367306644
# Iteration  305 : x-value is:  -0.033428657708821 f(x) is:  15.000113315834211
# Iteration  306 : x-value is:  -0.03332659071698198 f(x) is:  15.000112277267883
# Iteration  307 : x-value is:  -0.03322515058594062 f(x) is:  15.000111251409573
# Iteration  308 : x-value is:  -0.03312433152523081 f(x) is:  15.000110238064835
# Iteration  309 : x-value is:  -0.03302412781578583 f(x) is:  15.000109237042794
# Iteration  310 : x-value is:  -0.03292453380883758 f(x) is:  15.00010824815607
# Iteration  311 : x-value is:  -0.03282554392483622 f(x) is:  15.0001072712207
# Iteration  312 : x-value is:  -0.03272715265238969 f(x) is:  15.000106306056066
# Iteration  313 : x-value is:  -0.032629354547222746 f(x) is:  15.000105352484827
# Iteration  314 : x-value is:  -0.03253214423115502 f(x) is:  15.000104410332844
# Iteration  315 : x-value is:  -0.03243551639109781 f(x) is:  15.000103479429118
# Iteration  316 : x-value is:  -0.03233946577806909 f(x) is:  15.000102559605724
# Iteration  317 : x-value is:  -0.032243987206226406 f(x) is:  15.00010165069774
# Iteration  318 : x-value is:  -0.03214907555191728 f(x) is:  15.000100752543196
# Iteration  319 : x-value is:  -0.03205472575274677 f(x) is:  15.000099864982998
# Iteration  320 : x-value is:  -0.03196093280666172 f(x) is:  15.00009898786088
# Iteration  321 : x-value is:  -0.031867691771051566 f(x) is:  15.000098121023342
# Iteration  322 : x-value is:  -0.03177499776186506 f(x) is:  15.000097264319589
# Iteration  323 : x-value is:  -0.03168284595274287 f(x) is:  15.000096417601478
# Iteration  324 : x-value is:  -0.0315912315741655 f(x) is:  15.000095580723471
# Iteration  325 : x-value is:  -0.03150014991261636 f(x) is:  15.00009475354257
# Iteration  326 : x-value is:  -0.031409596309759626 f(x) is:  15.000093935918265
# Iteration  327 : x-value is:  -0.031319566161632506 f(x) is:  15.000093127712502
# Iteration  328 : x-value is:  -0.031230054917851774 f(x) is:  15.000092328789604
# Iteration  329 : x-value is:  -0.031141058080834148 f(x) is:  15.000091539016253
# Iteration  330 : x-value is:  -0.031052571205030285 f(x) is:  15.000090758261418
# Iteration  331 : x-value is:  -0.030964589896172116 f(x) is:  15.000089986396326
# Iteration  332 : x-value is:  -0.030877109810533217 f(x) is:  15.000089223294403
# Iteration  333 : x-value is:  -0.03079012665420201 f(x) is:  15.000088468831246
# Iteration  334 : x-value is:  -0.030703636182367478 f(x) is:  15.000087722884562
# Iteration  335 : x-value is:  -0.03061763419861718 f(x) is:  15.000086985334141
# Iteration  336 : x-value is:  -0.03053211655424728 f(x) is:  15.000086256061808
# Iteration  337 : x-value is:  -0.030447079147584422 f(x) is:  15.00008553495138
# Iteration  338 : x-value is:  -0.030362517923319114 f(x) is:  15.000084821888635
# Iteration  339 : x-value is:  -0.030278428871850494 f(x) is:  15.000084116761265
# Iteration  340 : x-value is:  -0.030194808028642165 f(x) is:  15.000083419458843
# Iteration  341 : x-value is:  -0.030111651473588956 f(x) is:  15.000082729872789
# Iteration  342 : x-value is:  -0.03002895533039433 f(x) is:  15.000082047896326
# Iteration  343 : x-value is:  -0.02994671576595826 f(x) is:  15.000081373424454
# Iteration  344 : x-value is:  -0.029864928989775396 f(x) is:  15.000080706353906
# Iteration  345 : x-value is:  -0.02978359125334324 f(x) is:  15.000080046583127
# Iteration  346 : x-value is:  -0.029702698849580236 f(x) is:  15.000079394012227
# Iteration  347 : x-value is:  -0.02962224811225349 f(x) is:  15.00007874854296
# Iteration  348 : x-value is:  -0.02954223541541601 f(x) is:  15.000078110078684
# Iteration  349 : x-value is:  -0.029462657172853218 f(x) is:  15.000077478524343
# Iteration  350 : x-value is:  -0.0293835098375386 f(x) is:  15.000076853786421
# Iteration  351 : x-value is:  -0.029304789901098298 f(x) is:  15.000076235772925
# Iteration  352 : x-value is:  -0.029226493893284487 f(x) is:  15.000075624393347
# Iteration  353 : x-value is:  -0.029148618381457336 f(x) is:  15.000075019558643
# Iteration  354 : x-value is:  -0.029071159970075436 f(x) is:  15.000074421181207
# Iteration  355 : x-value is:  -0.02899411530019451 f(x) is:  15.000073829174832
# Iteration  356 : x-value is:  -0.028917481048974222 f(x) is:  15.000073243454697
# Iteration  357 : x-value is:  -0.028841253929193 f(x) is:  15.000072663937337
# Iteration  358 : x-value is:  -0.028765430688770653 f(x) is:  15.00007209054061
# Iteration  359 : x-value is:  -0.028690008110298655 f(x) is:  15.000071523183689
# Iteration  360 : x-value is:  -0.028614983010577997 f(x) is:  15.000070961787017
# Iteration  361 : x-value is:  -0.0285403522401644 f(x) is:  15.000070406272302
# Iteration  362 : x-value is:  -0.028466112682920788 f(x) is:  15.000069856562483
# Iteration  363 : x-value is:  -0.028392261255576874 f(x) is:  15.00006931258171
# Iteration  364 : x-value is:  -0.028318794907295754 f(x) is:  15.000068774255324
# Iteration  365 : x-value is:  -0.028245710619247327 f(x) is:  15.000068241509828
# Iteration  366 : x-value is:  -0.028173005404188465 f(x) is:  15.00006771427288
# Iteration  367 : x-value is:  -0.028100676306049788 f(x) is:  15.000067192473256
# Iteration  368 : x-value is:  -0.028028720399528917 f(x) is:  15.00006667604084
# Iteration  369 : x-value is:  -0.0279571347896901 f(x) is:  15.000066164906597
# Iteration  370 : x-value is:  -0.027885916611570083 f(x) is:  15.000065659002564
# Iteration  371 : x-value is:  -0.027815063029790123 f(x) is:  15.000065158261819
# Iteration  372 : x-value is:  -0.027744571238174025 f(x) is:  15.000064662618469
# Iteration  373 : x-value is:  -0.027674438459372088 f(x) is:  15.000064172007628
# Iteration  374 : x-value is:  -0.02760466194449088 f(x) is:  15.000063686365403
# Iteration  375 : x-value is:  -0.02753523897272869 f(x) is:  15.000063205628875
# Iteration  376 : x-value is:  -0.027466166851016598 f(x) is:  15.00006272973608
# Iteration  377 : x-value is:  -0.027397442913665058 f(x) is:  15.000062258625992
# Iteration  378 : x-value is:  -0.027329064522015858 f(x) is:  15.000061792238506
# Iteration  379 : x-value is:  -0.02726102906409941 f(x) is:  15.000061330514429
# Iteration  380 : x-value is:  -0.02719333395429723 f(x) is:  15.000060873395453
# Iteration  381 : x-value is:  -0.02712597663300958 f(x) is:  15.000060420824148
# Iteration  382 : x-value is:  -0.027058954566328078 f(x) is:  15.00005997274394
# Iteration  383 : x-value is:  -0.02699226524571331 f(x) is:  15.000059529099103
# Iteration  384 : x-value is:  -0.026925906187677248 f(x) is:  15.000059089834735
# Iteration  385 : x-value is:  -0.026859874933470484 f(x) is:  15.000058654896758
# Iteration  386 : x-value is:  -0.026794169048774095 f(x) is:  15.000058224231887
# Iteration  387 : x-value is:  -0.026728786123396162 f(x) is:  15.000057797787628
# Iteration  388 : x-value is:  -0.02666372377097278 f(x) is:  15.00005737551226
# Iteration  389 : x-value is:  -0.02659897962867352 f(x) is:  15.000056957354824
# Iteration  390 : x-value is:  -0.02653455135691128 f(x) is:  15.000056543265107
# Iteration  391 : x-value is:  -0.026470436639056377 f(x) is:  15.000056133193628
# Iteration  392 : x-value is:  -0.026406633181154934 f(x) is:  15.000055727091633
# Iteration  393 : x-value is:  -0.026343138711651334 f(x) is:  15.000055324911077
# Iteration  394 : x-value is:  -0.026279950981114797 f(x) is:  15.000054926604609
# Iteration  395 : x-value is:  -0.026217067761969946 f(x) is:  15.000054532125567
# Iteration  396 : x-value is:  -0.026154486848231316 f(x) is:  15.000054141427961
# Iteration  397 : x-value is:  -0.026092206055241717 f(x) is:  15.00005375446647
# Iteration  398 : x-value is:  -0.026030223219414426 f(x) is:  15.000053371196417
# Iteration  399 : x-value is:  -0.025968536197979092 f(x) is:  15.000052991573769
# Iteration  400 : x-value is:  -0.02590714286873133 f(x) is:  15.000052615555125
# Iteration  401 : x-value is:  -0.025846041129785936 f(x) is:  15.000052243097704
# Iteration  402 : x-value is:  -0.025785228899333625 f(x) is:  15.000051874159327
# Iteration  403 : x-value is:  -0.025724704115401315 f(x) is:  15.000051508698427
# Iteration  404 : x-value is:  -0.02566446473561578 f(x) is:  15.000051146674013
# Iteration  405 : x-value is:  -0.025604508736970743 f(x) is:  15.000050788045682
# Iteration  406 : x-value is:  -0.025544834115597242 f(x) is:  15.0000504327736
# Iteration  407 : x-value is:  -0.025485438886537294 f(x) is:  15.000050080818491
# Iteration  408 : x-value is:  -0.025426321083520755 f(x) is:  15.000049732141632
# Iteration  409 : x-value is:  -0.025367478758745336 f(x) is:  15.000049386704841
# Iteration  410 : x-value is:  -0.025308909982659746 f(x) is:  15.000049044470472
# Iteration  411 : x-value is:  -0.025250612843749867 f(x) is:  15.000048705401403
# Iteration  412 : x-value is:  -0.02519258544832794 f(x) is:  15.000048369461025
# Iteration  413 : x-value is:  -0.025134825920324722 f(x) is:  15.000048036613244
# Iteration  414 : x-value is:  -0.025077332401084524 f(x) is:  15.000047706822459
# Iteration  415 : x-value is:  -0.02502010304916314 f(x) is:  15.000047380053562
# Iteration  416 : x-value is:  -0.024963136040128564 f(x) is:  15.000047056271933
# Iteration  417 : x-value is:  -0.024906429566364487 f(x) is:  15.000046735443423
# Iteration  418 : x-value is:  -0.024849981836876516 f(x) is:  15.000046417534353
# Iteration  419 : x-value is:  -0.024793791077101075 f(x) is:  15.000046102511506
# Iteration  420 : x-value is:  -0.024737855528716924 f(x) is:  15.000045790342115
# Iteration  421 : x-value is:  -0.02468217344945931 f(x) is:  15.000045480993867
# Iteration  422 : x-value is:  -0.024626743112936618 f(x) is:  15.000045174434877
# Iteration  423 : x-value is:  -0.024571562808449583 f(x) is:  15.000044870633703
# Iteration  424 : x-value is:  -0.024516630840812938 f(x) is:  15.00004456955932
# Iteration  425 : x-value is:  -0.024461945530179507 f(x) is:  15.000044271181128
# Iteration  426 : x-value is:  -0.0244075052118667 f(x) is:  15.000043975468934
# Iteration  427 : x-value is:  -0.024353308236185346 f(x) is:  15.000043682392956
# Iteration  428 : x-value is:  -0.024299352968270845 f(x) is:  15.000043391923805
# Iteration  429 : x-value is:  -0.02424563778791662 f(x) is:  15.000043104032489
# Iteration  430 : x-value is:  -0.024192161089409796 f(x) is:  15.000042818690403
# Iteration  431 : x-value is:  -0.024138921281369085 f(x) is:  15.000042535869323
# Iteration  432 : x-value is:  -0.02408591678658487 f(x) is:  15.000042255541397
# Iteration  433 : x-value is:  -0.024033146041861405 f(x) is:  15.000041977679144
# Iteration  434 : x-value is:  -0.023980607497861146 f(x) is:  15.00004170225545
# Iteration  435 : x-value is:  -0.023928299618951123 f(x) is:  15.00004142924355
# Iteration  436 : x-value is:  -0.0238762208830514 f(x) is:  15.00004115861704
# Iteration  437 : x-value is:  -0.0238243697814855 f(x) is:  15.000040890349862
# Iteration  438 : x-value is:  -0.02377274481883285 f(x) is:  15.000040624416291
# Iteration  439 : x-value is:  -0.023721344512783155 f(x) is:  15.00004036079095
# Iteration  440 : x-value is:  -0.023670167393992674 f(x) is:  15.000040099448785
# Iteration  441 : x-value is:  -0.02361921200594243 f(x) is:  15.000039840365073
# Iteration  442 : x-value is:  -0.023568476904798245 f(x) is:  15.00003958351541
# Iteration  443 : x-value is:  -0.023517960659272617 f(x) is:  15.000039328875708
# Iteration  444 : x-value is:  -0.023467661850488406 f(x) is:  15.00003907642219
# Iteration  445 : x-value is:  -0.0234175790718443 f(x) is:  15.00003882613139
# Iteration  446 : x-value is:  -0.023367710928882006 f(x) is:  15.000038577980142
# Iteration  447 : x-value is:  -0.02331805603915521 f(x) is:  15.000038331945575
# Iteration  448 : x-value is:  -0.023268613032100184 f(x) is:  15.000038088005113
# Iteration  449 : x-value is:  -0.023219380548908097 f(x) is:  15.000037846136472
# Iteration  450 : x-value is:  -0.02317035724239897 f(x) is:  15.00003760631765
# Iteration  451 : x-value is:  -0.02312154177689724 f(x) is:  15.000037368526922
# Iteration  452 : x-value is:  -0.02307293282810892 f(x) is:  15.000037132742847
# Iteration  453 : x-value is:  -0.023024529083000348 f(x) is:  15.000036898944249
# Iteration  454 : x-value is:  -0.02297632923967849 f(x) is:  15.000036667110223
# Iteration  455 : x-value is:  -0.022928332007272734 f(x) is:  15.000036437220128
# Iteration  456 : x-value is:  -0.02288053610581823 f(x) is:  15.000036209253583
# Iteration  457 : x-value is:  -0.022832940266140685 f(x) is:  15.000035983190465
# Iteration  458 : x-value is:  -0.02278554322974263 f(x) is:  15.0000357590109
# Iteration  459 : x-value is:  -0.022738343748691124 f(x) is:  15.000035536695266
# Iteration  460 : x-value is:  -0.02269134058550687 f(x) is:  15.000035316224187
# Iteration  461 : x-value is:  -0.022644532513054726 f(x) is:  15.000035097578523
# Iteration  462 : x-value is:  -0.022597918314435608 f(x) is:  15.00003488073938
# Iteration  463 : x-value is:  -0.02255149678287973 f(x) is:  15.000034665688093
# Iteration  464 : x-value is:  -0.022505266721641187 f(x) is:  15.00003445240623
# Iteration  465 : x-value is:  -0.02245922694389385 f(x) is:  15.000034240875587
# Iteration  466 : x-value is:  -0.022413376272628568 f(x) is:  15.000034031078188
# Iteration  467 : x-value is:  -0.02236771354055164 f(x) is:  15.000033822996272
# Iteration  468 : x-value is:  -0.022322237589984542 f(x) is:  15.000033616612303
# Iteration  469 : x-value is:  -0.022276947272764924 f(x) is:  15.000033411908953
# Iteration  470 : x-value is:  -0.022231841450148778 f(x) is:  15.000033208869114
# Iteration  471 : x-value is:  -0.022186918992713873 f(x) is:  15.000033007475881
# Iteration  472 : x-value is:  -0.02214217878026432 f(x) is:  15.000032807712556
# Iteration  473 : x-value is:  -0.022097619701736366 f(x) is:  15.000032609562648
# Iteration  474 : x-value is:  -0.022053240655105288 f(x) is:  15.000032413009862
# Iteration  475 : x-value is:  -0.022009040547293465 f(x) is:  15.000032218038102
# Iteration  476 : x-value is:  -0.02196501829407956 f(x) is:  15.000032024631466
# Iteration  477 : x-value is:  -0.0219211728200088 f(x) is:  15.000031832774246
# Iteration  478 : x-value is:  -0.02187750305830435 f(x) is:  15.00003164245092
# Iteration  479 : x-value is:  -0.021834007950779777 f(x) is:  15.000031453646159
# Iteration  480 : x-value is:  -0.021790686447752547 f(x) is:  15.000031266344806
# Iteration  481 : x-value is:  -0.021747537507958586 f(x) is:  15.000031080531897
# Iteration  482 : x-value is:  -0.02170456009846787 f(x) is:  15.00003089619264
# Iteration  483 : x-value is:  -0.021661753194601025 f(x) is:  15.000030713312425
# Iteration  484 : x-value is:  -0.021619115779846924 f(x) is:  15.00003053187681
# Iteration  485 : x-value is:  -0.021576646845781287 f(x) is:  15.000030351871528
# Iteration  486 : x-value is:  -0.02153434539198623 f(x) is:  15.000030173282479
# Iteration  487 : x-value is:  -0.021492210425970812 f(x) is:  15.000029996095732
# Iteration  488 : x-value is:  -0.021450240963092476 f(x) is:  15.000029820297518
# Iteration  489 : x-value is:  -0.021408436026479474 f(x) is:  15.000029645874234
# Iteration  490 : x-value is:  -0.021366794646954186 f(x) is:  15.00002947281243
# Iteration  491 : x-value is:  -0.021325315862957342 f(x) is:  15.000029301098824
# Iteration  492 : x-value is:  -0.021283998720473166 f(x) is:  15.000029130720279
# Iteration  493 : x-value is:  -0.02124284227295537 f(x) is:  15.00002896166382
# Iteration  494 : x-value is:  -0.021201845581254045 f(x) is:  15.000028793916615
# Iteration  495 : x-value is:  -0.021161007713543394 f(x) is:  15.000028627465989
# Iteration  496 : x-value is:  -0.02112032774525032 f(x) is:  15.000028462299413
# Iteration  497 : x-value is:  -0.021079804758983852 f(x) is:  15.000028298404498
# Iteration  498 : x-value is:  -0.02103943784446538 f(x) is:  15.000028135769005
# Iteration  499 : x-value is:  -0.020999226098459733 f(x) is:  15.000027974380831
# Iteration  500 : x-value is:  -0.020959168624707012 f(x) is:  15.000027814228016
# Iteration  501 : x-value is:  -0.02091926453385527 f(x) is:  15.000027655298737
# Iteration  502 : x-value is:  -0.020879512943393918 f(x) is:  15.000027497581305
# Iteration  503 : x-value is:  -0.020839912977587947 f(x) is:  15.000027341064168
# Iteration  504 : x-value is:  -0.020800463767412878 f(x) is:  15.000027185735902
# Iteration  505 : x-value is:  -0.02076116445049047 f(x) is:  15.000027031585219
# Iteration  506 : x-value is:  -0.020722014171025174 f(x) is:  15.000026878600954
# Iteration  507 : x-value is:  -0.020683012079741308 f(x) is:  15.000026726772072
# Iteration  508 : x-value is:  -0.020644157333820957 f(x) is:  15.000026576087663
# Iteration  509 : x-value is:  -0.020605449096842574 f(x) is:  15.00002642653694
# Iteration  510 : x-value is:  -0.020566886538720287 f(x) is:  15.000026278109237
# Iteration  511 : x-value is:  -0.020528468835643906 f(x) is:  15.000026130794014
# Iteration  512 : x-value is:  -0.020490195170019595 f(x) is:  15.00002598458084
# Iteration  513 : x-value is:  -0.020452064730411224 f(x) is:  15.000025839459413
# Iteration  514 : x-value is:  -0.020414076711482387 f(x) is:  15.000025695419534
# Iteration  515 : x-value is:  -0.020376230313939078 f(x) is:  15.00002555245113
# Iteration  516 : x-value is:  -0.020338524744473004 f(x) is:  15.00002541054423
# Iteration  517 : x-value is:  -0.02030095921570554 f(x) is:  15.000025269688985
# Iteration  518 : x-value is:  -0.02026353294613232 f(x) is:  15.000025129875645
# Iteration  519 : x-value is:  -0.02022624516006843 f(x) is:  15.000024991094579
# Iteration  520 : x-value is:  -0.020189095087594255 f(x) is:  15.000024853336253
# Iteration  521 : x-value is:  -0.020152081964501873 f(x) is:  15.000024716591245
# Iteration  522 : x-value is:  -0.0201152050322421 f(x) is:  15.000024580850235
# Iteration  523 : x-value is:  -0.02007846353787209 f(x) is:  15.000024446104009
# Iteration  524 : x-value is:  -0.020041856734003535 f(x) is:  15.000024312343447
# Iteration  525 : x-value is:  -0.020005383878751434 f(x) is:  15.000024179559535
# Iteration  526 : x-value is:  -0.019969044235683422 f(x) is:  15.00002404774336
# Iteration  527 : x-value is:  -0.019932837073769673 f(x) is:  15.0000239168861
# Iteration  528 : x-value is:  -0.01989676166733334 f(x) is:  15.000023786979034
# Iteration  529 : x-value is:  -0.019860817296001552 f(x) is:  15.000023658013536
# Iteration  530 : x-value is:  -0.019825003244656948 f(x) is:  15.000023529981073
# Iteration  531 : x-value is:  -0.019789318803389733 f(x) is:  15.000023402873204
# Iteration  532 : x-value is:  -0.01975376326745027 f(x) is:  15.00002327668158
# Iteration  533 : x-value is:  -0.01971833593720218 f(x) is:  15.000023151397945
# Iteration  534 : x-value is:  -0.019683036118075967 f(x) is:  15.000023027014128
# Iteration  535 : x-value is:  -0.019647863120523124 f(x) is:  15.00002290352205
# Iteration  536 : x-value is:  -0.019612816259970772 f(x) is:  15.000022780913717
# Iteration  537 : x-value is:  -0.019577894856776763 f(x) is:  15.000022659181221
# Iteration  538 : x-value is:  -0.019543098236185268 f(x) is:  15.000022538316742
# Iteration  539 : x-value is:  -0.01950842572828287 f(x) is:  15.000022418312538
# Iteration  540 : x-value is:  -0.01947387666795511 f(x) is:  15.000022299160953
# Iteration  541 : x-value is:  -0.019439450394843495 f(x) is:  15.000022180854414
# Iteration  542 : x-value is:  -0.019405146253302998 f(x) is:  15.000022063385428
# Iteration  543 : x-value is:  -0.019370963592359985 f(x) is:  15.00002194674658
# Iteration  544 : x-value is:  -0.019336901765670596 f(x) is:  15.000021830930537
# Iteration  545 : x-value is:  -0.019302960131479585 f(x) is:  15.000021715930039
# Iteration  546 : x-value is:  -0.01926913805257959 f(x) is:  15.000021601737906
# Iteration  547 : x-value is:  -0.01923543489627084 f(x) is:  15.000021488347036
# Iteration  548 : x-value is:  -0.019201850034321285 f(x) is:  15.000021375750396
# Iteration  549 : x-value is:  -0.01916838284292715 f(x) is:  15.000021263941033
# Iteration  550 : x-value is:  -0.019135032702673915 f(x) is:  15.000021152912062
# Iteration  551 : x-value is:  -0.019101798998497697 f(x) is:  15.000021042656675
# Iteration  552 : x-value is:  -0.019068681119647053 f(x) is:  15.00002093316813
# Iteration  553 : x-value is:  -0.019035678459645163 f(x) is:  15.000020824439762
# Iteration  554 : x-value is:  -0.019002790416252434 f(x) is:  15.000020716464968
# Iteration  555 : x-value is:  -0.018970016391429485 f(x) is:  15.000020609237222
# Iteration  556 : x-value is:  -0.018937355791300528 f(x) is:  15.000020502750058
# Iteration  557 : x-value is:  -0.018904808026117118 f(x) is:  15.000020396997082
# Iteration  558 : x-value is:  -0.01887237251022229 f(x) is:  15.000020291971966
# Iteration  559 : x-value is:  -0.01884004866201508 f(x) is:  15.000020187668444
# Iteration  560 : x-value is:  -0.018807835903915392 f(x) is:  15.000020084080319
# Iteration  561 : x-value is:  -0.01877573366232925 f(x) is:  15.000019981201456
# Iteration  562 : x-value is:  -0.018743741367614405 f(x) is:  15.000019879025782
# Iteration  563 : x-value is:  -0.018711858454046295 f(x) is:  15.000019777547287
# Iteration  564 : x-value is:  -0.01868008435978435 f(x) is:  15.000019676760026
# Iteration  565 : x-value is:  -0.01864841852683867 f(x) is:  15.000019576658108
# Iteration  566 : x-value is:  -0.018616860401037015 f(x) is:  15.00001947723571
# Iteration  567 : x-value is:  -0.01858540943199215 f(x) is:  15.000019378487062
# Iteration  568 : x-value is:  -0.018554065073069535 f(x) is:  15.000019280406455
# Iteration  569 : x-value is:  -0.018522826781355316 f(x) is:  15.000019182988241
# Iteration  570 : x-value is:  -0.018491694017624686 f(x) is:  15.000019086226825
# Iteration  571 : x-value is:  -0.018460666246310518 f(x) is:  15.00001899011667
# Iteration  572 : x-value is:  -0.018429742935472365 f(x) is:  15.000018894652298
# Iteration  573 : x-value is:  -0.018398923556765753 f(x) is:  15.000018799828279
# Iteration  574 : x-value is:  -0.018368207585411776 f(x) is:  15.000018705639247
# Iteration  575 : x-value is:  -0.018337594500167025 f(x) is:  15.000018612079883
# Iteration  576 : x-value is:  -0.0183070837832938 f(x) is:  15.000018519144923
# Iteration  577 : x-value is:  -0.018276674920530638 f(x) is:  15.000018426829161
# Iteration  578 : x-value is:  -0.018246367401063127 f(x) is:  15.000018335127434
# Iteration  579 : x-value is:  -0.018216160717495017 f(x) is:  15.000018244034637
# Iteration  580 : x-value is:  -0.018186054365819625 f(x) is:  15.000018153545716
# Iteration  581 : x-value is:  -0.018156047845391522 f(x) is:  15.000018063655665
# Iteration  582 : x-value is:  -0.018126140658898515 f(x) is:  15.000017974359526
# Iteration  583 : x-value is:  -0.01809633231233389 f(x) is:  15.000017885652396
# Iteration  584 : x-value is:  -0.018066622314968958 f(x) is:  15.000017797529415
# Iteration  585 : x-value is:  -0.018037010179325838 f(x) is:  15.000017709985775
# Iteration  586 : x-value is:  -0.01800749542115055 f(x) is:  15.000017623016713
# Iteration  587 : x-value is:  -0.01797807755938636 f(x) is:  15.000017536617515
# Iteration  588 : x-value is:  -0.017948756116147373 f(x) is:  15.00001745078351
# Iteration  589 : x-value is:  -0.017919530616692415 f(x) is:  15.000017365510079
# Iteration  590 : x-value is:  -0.017890400589399155 f(x) is:  15.00001728079264
# Iteration  591 : x-value is:  -0.017861365565738488 f(x) is:  15.000017196626663
# Iteration  592 : x-value is:  -0.01783242508024917 f(x) is:  15.00001711300766
# Iteration  593 : x-value is:  -0.017803578670512712 f(x) is:  15.000017029931186
# Iteration  594 : x-value is:  -0.017774825877128496 f(x) is:  15.00001694739284
# Iteration  595 : x-value is:  -0.017746166243689163 f(x) is:  15.000016865388265
# Iteration  596 : x-value is:  -0.017717599316756222 f(x) is:  15.000016783913143
# Iteration  597 : x-value is:  -0.01768912464583591 f(x) is:  15.000016702963201
# Iteration  598 : x-value is:  -0.01766074178335528 f(x) is:  15.000016622534206
# Iteration  599 : x-value is:  -0.01763245028463853 f(x) is:  15.000016542621966
# Iteration  600 : x-value is:  -0.01760424970788354 f(x) is:  15.000016463222332
# ...
# Iteration  828 : x-value is:  -0.0129049547384054 f(x) is:  15.000006475225371
# Iteration  829 : x-value is:  -0.012889880364753204 f(x) is:  15.000006452528305
# Iteration  830 : x-value is:  -0.012874841287692151 f(x) is:  15.000006429937375
# Iteration  831 : x-value is:  -0.01285983738311583 f(x) is:  15.000006407451957
# Iteration  832 : x-value is:  -0.012844868527499954 f(x) is:  15.000006385071439
# Iteration  833 : x-value is:  -0.012829934597898955 f(x) is:  15.000006362795206
# Iteration  834 : x-value is:  -0.012815035471942588 f(x) is:  15.000006340622653
# Iteration  835 : x-value is:  -0.012800171027832565 f(x) is:  15.000006318553174
# Iteration  836 : x-value is:  -0.012785341144339218 f(x) is:  15.000006296586172
# Iteration  837 : x-value is:  -0.012770545700798172 f(x) is:  15.00000627472105
# Iteration  838 : x-value is:  -0.01275578457710706 f(x) is:  15.00000625295722
# Iteration  839 : x-value is:  -0.012741057653722238 f(x) is:  15.000006231294094
# Iteration  840 : x-value is:  -0.012726364811655547 f(x) is:  15.000006209731088
# Iteration  841 : x-value is:  -0.01271170593247108 f(x) is:  15.000006188267626
# Iteration  842 : x-value is:  -0.012697080898281976 f(x) is:  15.00000616690313
# Iteration  843 : x-value is:  -0.012682489591747245 f(x) is:  15.000006145637034
# Iteration  844 : x-value is:  -0.012667931896068598 f(x) is:  15.000006124468769
# Iteration  845 : x-value is:  -0.012653407694987321 f(x) is:  15.000006103397773
# Iteration  846 : x-value is:  -0.012638916872781146 f(x) is:  15.000006082423486
# Iteration  847 : x-value is:  -0.012624459314261167 f(x) is:  15.000006061545353
# Iteration  848 : x-value is:  -0.012610034904768759 f(x) is:  15.000006040762823
# Iteration  849 : x-value is:  -0.01259564353017253 f(x) is:  15.00000602007535
# Iteration  850 : x-value is:  -0.012581285076865288 f(x) is:  15.000005999482392
# Iteration  851 : x-value is:  -0.012566959431761036 f(x) is:  15.000005978983404
# Iteration  852 : x-value is:  -0.012552666482291976 f(x) is:  15.000005958577853
# Iteration  853 : x-value is:  -0.012538406116405543 f(x) is:  15.000005938265208
# Iteration  854 : x-value is:  -0.012524178222561458 f(x) is:  15.000005918044938
# Iteration  855 : x-value is:  -0.012509982689728796 f(x) is:  15.000005897916518
# Iteration  856 : x-value is:  -0.012495819407383084 f(x) is:  15.000005877879426
# Iteration  857 : x-value is:  -0.012481688265503409 f(x) is:  15.000005857933145
# Iteration  858 : x-value is:  -0.012467589154569548 f(x) is:  15.00000583807716
# Iteration  859 : x-value is:  -0.012453521965559124 f(x) is:  15.00000581831096
# Iteration  860 : x-value is:  -0.012439486589944775 f(x) is:  15.000005798634037
# Iteration  861 : x-value is:  -0.01242548291969134 f(x) is:  15.000005779045887
# Iteration  862 : x-value is:  -0.012411510847253076 f(x) is:  15.00000575954601
# Iteration  863 : x-value is:  -0.012397570265570878 f(x) is:  15.000005740133908
# Iteration  864 : x-value is:  -0.012383661068069532 f(x) is:  15.000005720809087
# Iteration  865 : x-value is:  -0.012369783148654976 f(x) is:  15.000005701571057
# Iteration  866 : x-value is:  -0.012355936401711589 f(x) is:  15.00000568241933
# Iteration  867 : x-value is:  -0.012342120722099491 f(x) is:  15.000005663353422
# Iteration  868 : x-value is:  -0.012328336005151864 f(x) is:  15.000005644372854
# Iteration  869 : x-value is:  -0.012314582146672292 f(x) is:  15.000005625477144
# Iteration  870 : x-value is:  -0.012300859042932114 f(x) is:  15.000005606665821
# Iteration  871 : x-value is:  -0.012287166590667803 f(x) is:  15.000005587938416
# Iteration  872 : x-value is:  -0.012273504687078362 f(x) is:  15.000005569294457
# Iteration  873 : x-value is:  -0.012259873229822723 f(x) is:  15.00000555073348
# Iteration  874 : x-value is:  -0.012246272117017183 f(x) is:  15.000005532255024
# Iteration  875 : x-value is:  -0.012232701247232846 f(x) is:  15.000005513858628
# Iteration  876 : x-value is:  -0.012219160519493085 f(x) is:  15.00000549554384
# Iteration  877 : x-value is:  -0.012205649833271024 f(x) is:  15.000005477310207
# Iteration  878 : x-value is:  -0.012192169088487024 f(x) is:  15.000005459157277
# Iteration  879 : x-value is:  -0.012178718185506207 f(x) is:  15.000005441084605
# Iteration  880 : x-value is:  -0.012165297025135979 f(x) is:  15.000005423091746
# Iteration  881 : x-value is:  -0.012151905508623573 f(x) is:  15.000005405178262
# Iteration  882 : x-value is:  -0.01213854353765362 f(x) is:  15.000005387343712
# Iteration  883 : x-value is:  -0.012125211014345714 f(x) is:  15.000005369587665
# Iteration  884 : x-value is:  -0.01211190784125202 f(x) is:  15.000005351909685
# Iteration  885 : x-value is:  -0.01209863392135487 f(x) is:  15.000005334309344
# Iteration  886 : x-value is:  -0.012085389158064404 f(x) is:  15.000005316786217
# Iteration  887 : x-value is:  -0.012072173455216197 f(x) is:  15.00000529933988
# Iteration  888 : x-value is:  -0.012058986717068928 f(x) is:  15.000005281969912
# Iteration  889 : x-value is:  -0.012045828848302043 f(x) is:  15.000005264675895
# Iteration  890 : x-value is:  -0.012032699754013453 f(x) is:  15.000005247457414
# Iteration  891 : x-value is:  -0.012019599339717229 f(x) is:  15.000005230314056
# Iteration  892 : x-value is:  -0.012006527511341325 f(x) is:  15.000005213245412
# Iteration  893 : x-value is:  -0.011993484175225309 f(x) is:  15.000005196251076
# Iteration  894 : x-value is:  -0.01198046923811811 f(x) is:  15.000005179330639
# Iteration  895 : x-value is:  -0.01196748260717579 f(x) is:  15.000005162483705
# Iteration  896 : x-value is:  -0.01195452418995931 f(x) is:  15.00000514570987
# Iteration  897 : x-value is:  -0.011941593894432329 f(x) is:  15.000005129008741
# Iteration  898 : x-value is:  -0.01192869162895901 f(x) is:  15.000005112379924
# Iteration  899 : x-value is:  -0.01191581730230184 f(x) is:  15.000005095823024
# Iteration  900 : x-value is:  -0.011902970823619468 f(x) is:  15.000005079337654
# Iteration  901 : x-value is:  -0.01189015210246455 f(x) is:  15.00000506292343
# Iteration  902 : x-value is:  -0.011877361048781615 f(x) is:  15.000005046579965
# Iteration  903 : x-value is:  -0.011864597572904943 f(x) is:  15.000005030306879
# Iteration  904 : x-value is:  -0.011851861585556456 f(x) is:  15.000005014103793
# Iteration  905 : x-value is:  -0.01183915299784362 f(x) is:  15.000004997970331
# Iteration  906 : x-value is:  -0.01182647172125737 f(x) is:  15.000004981906118
# Iteration  907 : x-value is:  -0.011813817667670033 f(x) is:  15.000004965910781
# Iteration  908 : x-value is:  -0.011801190749333283 f(x) is:  15.000004949983955
# Iteration  909 : x-value is:  -0.011788590878876088 f(x) is:  15.000004934125268
# Iteration  910 : x-value is:  -0.011776017969302695 f(x) is:  15.000004918334362
# Iteration  911 : x-value is:  -0.011763471933990606 f(x) is:  15.000004902610868
# Iteration  912 : x-value is:  -0.011750952686688576 f(x) is:  15.00000488695443
# Iteration  913 : x-value is:  -0.011738460141514627 f(x) is:  15.00000487136469
# Iteration  914 : x-value is:  -0.011725994212954073 f(x) is:  15.000004855841294
# Iteration  915 : x-value is:  -0.011713554815857551 f(x) is:  15.000004840383884
# Iteration  916 : x-value is:  -0.011701141865439073 f(x) is:  15.000004824992116
# Iteration  917 : x-value is:  -0.011688755277274086 f(x) is:  15.000004809665636
# Iteration  918 : x-value is:  -0.011676394967297547 f(x) is:  15.000004794404102
# Iteration  919 : x-value is:  -0.01166406085180201 f(x) is:  15.000004779207167
# Iteration  920 : x-value is:  -0.01165175284743572 f(x) is:  15.00000476407449
# Iteration  921 : x-value is:  -0.011639470871200729 f(x) is:  15.000004749005733
# Iteration  922 : x-value is:  -0.011627214840451013 f(x) is:  15.000004734000555
# Iteration  923 : x-value is:  -0.011614984672890613 f(x) is:  15.000004719058623
# Iteration  924 : x-value is:  -0.011602780286571775 f(x) is:  15.000004704179604
# Iteration  925 : x-value is:  -0.01159060159989311 f(x) is:  15.000004689363166
# Iteration  926 : x-value is:  -0.011578448531597764 f(x) is:  15.000004674608979
# Iteration  927 : x-value is:  -0.0115663210007716 f(x) is:  15.00000465991672
# Iteration  928 : x-value is:  -0.011554218926841395 f(x) is:  15.000004645286058
# Iteration  929 : x-value is:  -0.01154214222957303 f(x) is:  15.000004630716674
# Iteration  930 : x-value is:  -0.011530090829069726 f(x) is:  15.000004616208246
# Iteration  931 : x-value is:  -0.011518064645770253 f(x) is:  15.000004601760455
# Iteration  932 : x-value is:  -0.011506063600447178 f(x) is:  15.000004587372986
# Iteration  933 : x-value is:  -0.011494087614205114 f(x) is:  15.000004573045523
# Iteration  934 : x-value is:  -0.011482136608478972 f(x) is:  15.000004558777752
# Iteration  935 : x-value is:  -0.011470210505032245 f(x) is:  15.000004544569363
# Iteration  936 : x-value is:  -0.011458309225955279 f(x) is:  15.000004530420046
# Iteration  937 : x-value is:  -0.01144643269366357 f(x) is:  15.000004516329497
# Iteration  938 : x-value is:  -0.011434580830896069 f(x) is:  15.000004502297408
# Iteration  939 : x-value is:  -0.011422753560713494 f(x) is:  15.000004488323476
# Iteration  940 : x-value is:  -0.011410950806496654 f(x) is:  15.000004474407401
# Iteration  941 : x-value is:  -0.011399172491944788 f(x) is:  15.000004460548881
# Iteration  942 : x-value is:  -0.011387418541073904 f(x) is:  15.000004446747623
# Iteration  943 : x-value is:  -0.011375688878215143 f(x) is:  15.000004433003326
# Iteration  944 : x-value is:  -0.01136398342801314 f(x) is:  15.0000044193157
# Iteration  945 : x-value is:  -0.011352302115424397 f(x) is:  15.00000440568445
# Iteration  946 : x-value is:  -0.011340644865715678 f(x) is:  15.000004392109286
# Iteration  947 : x-value is:  -0.0113290116044624 f(x) is:  15.000004378589923
# Iteration  948 : x-value is:  -0.011317402257547038 f(x) is:  15.00000436512607
# Iteration  949 : x-value is:  -0.011305816751157544 f(x) is:  15.000004351717443
# Iteration  950 : x-value is:  -0.011294255011785773 f(x) is:  15.000004338363762
# Iteration  951 : x-value is:  -0.011282716966225919 f(x) is:  15.000004325064742
# Iteration  952 : x-value is:  -0.011271202541572958 f(x) is:  15.000004311820103
# Iteration  953 : x-value is:  -0.011259711665221103 f(x) is:  15.00000429862957
# Iteration  954 : x-value is:  -0.01124824426486227 f(x) is:  15.000004285492864
# Iteration  955 : x-value is:  -0.011236800268484556 f(x) is:  15.000004272409711
# Iteration  956 : x-value is:  -0.011225379604370712 f(x) is:  15.00000425937984
# Iteration  957 : x-value is:  -0.011213982201096647 f(x) is:  15.000004246402977
# Iteration  958 : x-value is:  -0.01120260798752992 f(x) is:  15.000004233478855
# Iteration  959 : x-value is:  -0.01119125689282826 f(x) is:  15.000004220607202
# Iteration  960 : x-value is:  -0.011179928846438076 f(x) is:  15.000004207787756
# Iteration  961 : x-value is:  -0.011168623778093 f(x) is:  15.00000419502025
# Iteration  962 : x-value is:  -0.011157341617812412 f(x) is:  15.000004182304421
# Iteration  963 : x-value is:  -0.011146082295899994 f(x) is:  15.00000416964001
# Iteration  964 : x-value is:  -0.011134845742942285 f(x) is:  15.000004157026751
# Iteration  965 : x-value is:  -0.011123631889807244 f(x) is:  15.000004144464393
# Iteration  966 : x-value is:  -0.011112440667642828 f(x) is:  15.000004131952675
# Iteration  967 : x-value is:  -0.011101272007875569 f(x) is:  15.000004119491342
# Iteration  968 : x-value is:  -0.011090125842209166 f(x) is:  15.00000410708014
# Iteration  969 : x-value is:  -0.01107900210262309 f(x) is:  15.000004094718822
# Iteration  970 : x-value is:  -0.011067900721371185 f(x) is:  15.000004082407129
# Iteration  971 : x-value is:  -0.011056821630980287 f(x) is:  15.000004070144819
# Iteration  972 : x-value is:  -0.011045764764248848 f(x) is:  15.000004057931639
# Iteration  973 : x-value is:  -0.01103473005424557 f(x) is:  15.000004045767346
# Iteration  974 : x-value is:  -0.011023717434308047 f(x) is:  15.000004033651695
# Iteration  975 : x-value is:  -0.011012726838041413 f(x) is:  15.000004021584443
# Iteration  976 : x-value is:  -0.011001758199316999 f(x) is:  15.000004009565348
# Iteration  977 : x-value is:  -0.010990811452271003 f(x) is:  15.000003997594169
# Iteration  978 : x-value is:  -0.010979886531303157 f(x) is:  15.000003985670668
# Iteration  979 : x-value is:  -0.010968983371075413 f(x) is:  15.000003973794607
# Iteration  980 : x-value is:  -0.010958101906510634 f(x) is:  15.000003961965751
# Iteration  981 : x-value is:  -0.010947242072791286 f(x) is:  15.000003950183864
# Iteration  982 : x-value is:  -0.01093640380535815 f(x) is:  15.000003938448714
# Iteration  983 : x-value is:  -0.01092558703990903 f(x) is:  15.000003926760069
# Iteration  984 : x-value is:  -0.010914791712397474 f(x) is:  15.000003915117698
# Iteration  985 : x-value is:  -0.010904017759031508 f(x) is:  15.000003903521373
# Iteration  986 : x-value is:  -0.010893265116272362 f(x) is:  15.000003891970866
# Iteration  987 : x-value is:  -0.010882533720833224 f(x) is:  15.00000388046595
# Iteration  988 : x-value is:  -0.010871823509677983 f(x) is:  15.0000038690064
# Iteration  989 : x-value is:  -0.010861134420019992 f(x) is:  15.000003857591993
# Iteration  990 : x-value is:  -0.010850466389320834 f(x) is:  15.000003846222507
# Iteration  991 : x-value is:  -0.010839819355289089 f(x) is:  15.00000383489772
# Iteration  992 : x-value is:  -0.01082919325587912 f(x) is:  15.000003823617412
# Iteration  993 : x-value is:  -0.010818588029289864 f(x) is:  15.000003812381367
# Iteration  994 : x-value is:  -0.010808003613963618 f(x) is:  15.000003801189365
# Iteration  995 : x-value is:  -0.010797439948584843 f(x) is:  15.000003790041191
# Iteration  996 : x-value is:  -0.01078689697207898 f(x) is:  15.000003778936632
# Iteration  997 : x-value is:  -0.01077637462361126 f(x) is:  15.000003767875473
# Iteration  998 : x-value is:  -0.010765872842585525 f(x) is:  15.000003756857502
# Iteration  999 : x-value is:  -0.010755391568643064 f(x) is:  15.000003745882509
# Iteration  1000 : x-value is:  -0.010744930741661446 f(x) is:  15.000003734950285
# Iteration  1001 : x-value is:  -0.010734490301753361 f(x) is:  15.000003724060619
# Iteration  1002 : x-value is:  -0.01072407018926548 f(x) is:  15.000003713213307
# Iteration  1003 : x-value is:  -0.010713670344777304 f(x) is:  15.00000370240814
# Iteration  1004 : x-value is:  -0.010703290709100026 f(x) is:  15.000003691644915
# Iteration  1005 : x-value is:  -0.010692931223275411 f(x) is:  15.00000368092343
# Iteration  1006 : x-value is:  -0.010682591828574664 f(x) is:  15.000003670243478
# Iteration  1007 : x-value is:  -0.010672272466497318 f(x) is:  15.000003659604863
# Iteration  1008 : x-value is:  -0.010661973078770124 f(x) is:  15.000003649007382
# Iteration  1009 : x-value is:  -0.010651693607345948 f(x) is:  15.000003638450837
# Iteration  1010 : x-value is:  -0.010641433994402672 f(x) is:  15.00000362793503
# Iteration  1011 : x-value is:  -0.010631194182342103 f(x) is:  15.000003617459766
# Iteration  1012 : x-value is:  -0.010620974113788897 f(x) is:  15.000003607024848
# Iteration  1013 : x-value is:  -0.010610773731589467 f(x) is:  15.00000359663008
# Iteration  1014 : x-value is:  -0.010600592978810924 f(x) is:  15.000003586275271
# Iteration  1015 : x-value is:  -0.010590431798740007 f(x) is:  15.000003575960232
# Iteration  1016 : x-value is:  -0.010580290134882023 f(x) is:  15.000003565684766
# Iteration  1017 : x-value is:  -0.010570167930959792 f(x) is:  15.000003555448687
# Iteration  1018 : x-value is:  -0.010560065130912606 f(x) is:  15.000003545251806
# Iteration  1019 : x-value is:  -0.010549981678895181 f(x) is:  15.000003535093933
# Iteration  1020 : x-value is:  -0.010539917519276631 f(x) is:  15.000003524974884
# Iteration  1021 : x-value is:  -0.010529872596639428 f(x) is:  15.000003514894471
# Iteration  1022 : x-value is:  -0.010519846855778388 f(x) is:  15.000003504852513
# Iteration  1023 : x-value is:  -0.01050984024169965 f(x) is:  15.000003494848825
# Iteration  1024 : x-value is:  -0.010499852699619663 f(x) is:  15.000003484883223
# The local minimum occurs at:  -0.010499852699619663
